# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC_Machine/blob/main/Tinnitus_Dynamic_ML_Tunning_with_featSelect_SHAP_ROC_Cross_val_version_1030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
#dataset=pd.read_csv("/content/drive/MyDrive/SNU Research/Tinnitus/Tinnitus_ALR&EEG_2022.08.18_final.csv")
 
dataset=pd.read_csv("/content/drive/MyDrive/Iqram Sir/Tinnitus_ALR&EEG_2022.08.26_final.csv")

classes = np.array(sorted(list(set(dataset.iloc[:, 1]))))

# %%
dataset.head()
# Out:
#              Subjects SubjectTypeClass TestType  n0_gap_peak_ms_20ms  \
# 0      '06_HSO_60_01'          Control     Test                   96
# 1      '06_LSR_34_01'          Control     Test                  108
# 2      '07_KHJ_33_02'          Control     Test                  123
# 3      '08_LJS_26_01'          Control     Test                   98
# 4      '09_JBH_58_01'          Control     Test                  127
#
#    p1_gap_peak_ms_20ms  n1_gap_peak_ms_20ms  p2_gap_peak_ms_20ms  \
# 0                  177                  213                  304
# 1                  151                  219                  282
# 2                  195                  246                  275
# 3                  163                  212                  320
# 4                  166                  206                  271
#
#    n2_gap_peak_ms_20ms  p3_gap_peak_ms_20ms  n0_nogap_peak_ms_20ms  ...  \
# 0                  425                  135                    175  ...
# 1                  390                  126                    152  ...
# 2                  456                   99                    166  ...
# 3                  416                  134                    197  ...
# 4                  386                  119                    153  ...
#
#    MeanP_Gamma_50ms  TotalEEGPower_50ms  RelativeAlpha_50ms  \
# 0      4.670000e-07            0.000055              0.0949
# 1      5.330000e-07            0.000047              0.1210
# 2      2.890000e-05            0.000778              0.0805
# 3      5.990000e-07            0.000075              0.0885
# 4      8.390000e-07            0.000074              0.1090
#
#    RelativeBeta_50ms  RelativeTheta_50ms  RelativeDelta_50ms  DTR_50ms  \
# 0             0.0372               0.387               0.481     1.240
# 1             0.0500               0.419               0.410     0.979
# 2             0.0527               0.301               0.566     1.880
# 3             0.0397               0.354               0.518     1.460
# 4             0.0564               0.392               0.442     1.130
#
#    DTABR_50ms  ATR_50ms  ABR_50ms
# 0        6.57     0.245      2.55
# 1        4.83     0.290      2.43
# 2        6.51     0.268      1.53
# 3        6.80     0.250      2.23
# 4        5.04     0.278      1.93
#
# [5 rows x 275 columns]

# %%
set(list(dataset['SubjectTypeClass']))
# Out:
# {'Control', 'Patient'}

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset.iloc[:, 1]=encoder.fit_transform(dataset.iloc[:, 1])

# %%
set(list(dataset['SubjectTypeClass']))
# Out:
# {0, 1}

# %% [markdown]
# #Feature Selection (User Defined with Index Range)

# %% [markdown]
# *   Index- [245]  to  [274] -> EEG Features
# *   Index- [4]    to  [243] -> Normal Features

# %%
'''
list_of_feat=[]
norm_start=int(input("Normal Features Start Index:"))
norm_end=int(input("Normal Features End Index:"))
eeg_start=int(input("EEG Features Start Index:"))
eeg_end=int(input("EEG Features End Index:"))



list_of_feat=list(dataset.iloc[:0,norm_start:norm_end])+list(dataset.iloc[:0,eeg_start:eeg_end])
'''
# Out:
# '\nlist_of_feat=[]\nnorm_start=int(input("Normal Features Start Index:"))\nnorm_end=int(input("Normal Features End Index:"))\neeg_start=int(input("EEG Features Start Index:"))\neeg_end=int(input("EEG Features End Index:"))\n\n\n\nlist_of_feat=list(dataset.iloc[:0,norm_start:norm_end])+list(dataset.iloc[:0,eeg_start:eeg_end])\n'

# %% [markdown]
# #Feature Selection (User Defined with Individual Feature)

# %% [markdown]
# **Please Input 'Subject' colunm name first**

# %%
'''list_of_feat=[]
num=int(input("Input number of features: "))

for i in range(num):
  print(i+1,".")
  list_of_feat.append(input("Feature Name: "))'''
# Out:
# 'list_of_feat=[]\nnum=int(input("Input number of features: "))\n\nfor i in range(num):\n  print(i+1,".")\n  list_of_feat.append(input("Feature Name: "))'

# %% [markdown]
# #Feature Selection (Model Free)

# %% [markdown]
# <font color='red'> Warning: Run only one Type at a time</font>

# %% [markdown]
# **Type-1**

# %%
'''from sklearn.feature_selection import SelectKBest
bestfeatures_1 = SelectKBest(k=10)
fit = bestfeatures_1.fit(X_,y_)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']'''
# Out:
# "from sklearn.feature_selection import SelectKBest\nbestfeatures_1 = SelectKBest(k=10)\nfit = bestfeatures_1.fit(X_,y_)\ndfscores = pd.DataFrame(fit.scores_)\ndfcolumns = pd.DataFrame(X_.columns)\nfeatureScores = pd.concat([dfcolumns,dfscores],axis=1)\nfeatureScores.columns = ['Specs','Score']"

# %% [markdown]
# **Type-2**

# %%
'''
from sklearn.feature_selection import SelectKBest,f_classif
bestfeatures_2=SelectKBest(f_classif, k=10)
fit = bestfeatures_f2fit(X_,y_)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']
'''
# Out:
# "\nfrom sklearn.feature_selection import SelectKBest,f_classif\nbestfeatures_2=SelectKBest(f_classif, k=10)\nfit = bestfeatures_f2fit(X_,y_)\ndfscores = pd.DataFrame(fit.scores_)\ndfcolumns = pd.DataFrame(X_.columns)\nfeatureScores = pd.concat([dfcolumns,dfscores],axis=1)\nfeatureScores.columns = ['Specs','Score']\n"

# %% [markdown]
# **Type-3**

# %%
'''
from sklearn.feature_selection import SelectFpr, f_classif

bestfeatures_3=SelectFpr(f_classif, alpha=0.1)
fit = bestfeatures_3.fit(X_,y_)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']
'''
# Out:
# "\nfrom sklearn.feature_selection import SelectFpr, f_classif\n\nbestfeatures_3=SelectFpr(f_classif, alpha=0.1)\nfit = bestfeatures_3.fit(X_,y_)\ndfscores = pd.DataFrame(fit.scores_)\ndfcolumns = pd.DataFrame(X_.columns)\nfeatureScores = pd.concat([dfcolumns,dfscores],axis=1)\nfeatureScores.columns = ['Specs','Score']\n"

# %% [markdown]
# <font color='blue' size=6><b>Input</b></font>

# %%
'''number_of_feat=int(input("Number Of Best Features: "))'''
# Out:
# 'number_of_feat=int(input("Number Of Best Features: "))'

# %%
'''imp=featureScores.nlargest(number_of_feat,'Score')
print(imp)'''
# Out:
# "imp=featureScores.nlargest(number_of_feat,'Score')\nprint(imp)"

# %%
'''
list_of_feat=[]

for i in range(number_of_feat):
  list_of_feat.append(imp.iloc[:,0:1].values[i][0])
  '''
# Out:
# '\nlist_of_feat=[]\n\nfor i in range(number_of_feat):\n  list_of_feat.append(imp.iloc[:,0:1].values[i][0])\n  '

# %% [markdown]
# #Feature Selection (Model Based)

# %% [markdown]
# <font color='blue' size=6><b>Input</b></font>

# %%
'''number_of_feat=int(input("Number Of Best Features: "))'''
# Out:
# 'number_of_feat=int(input("Number Of Best Features: "))'

# %%
'''from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
sfs = SequentialFeatureSelector(knn, n_features_to_select=number_of_feat)
sfs.fit(X_, y_)
list_of_feat=[]
list_of_feat=list(sfs.get_feature_names_out(list(dataset.iloc[:0,4:])))'''
# Out:
# 'from sklearn.feature_selection import SequentialFeatureSelector\nfrom sklearn.neighbors import KNeighborsClassifier\nknn = KNeighborsClassifier(n_neighbors=3)\nsfs = SequentialFeatureSelector(knn, n_features_to_select=number_of_feat)\nsfs.fit(X_, y_)\nlist_of_feat=[]\nlist_of_feat=list(sfs.get_feature_names_out(list(dataset.iloc[:0,4:])))'

# %% [markdown]
# #Data Spliting

# %% [markdown]
# You can remove it. I added for not to input all the features for every runtime

# %%
list_of_feat=["Subjects",
              "p3_gap_peak_amp_20ms",
    "p3_gap_peak_amp_50ms",
    "p1_gap_peak_amp_20ms",
    "p1_gap_peak_amp_50ms",
    "gap_AUC_n1p2_R_20ms",
    "gap_AUC_n1p2_R_50ms",
    "n1p3_interval_nogap_20ms",
    "n1p3_interval_nogap_50ms",
    "n2_gap_peak_amp_20ms",
    "n2_gap_peak_amp_50ms",
    "p2n2_gap_nogap_diff_20ms",
    "p2n2_gap_nogap_diff_50ms",
    "gap_AUC_n1p2_L_20ms",
    "gap_AUC_n1p2_L_50ms",
    "gap_AUC_p1n1_R_20ms",
    "gap_AUC_p1n1_R_50ms",
    "gap_AUC_n1p2n2_20ms",
    "gap_AUC_n1p2n2_50ms",
    "n2_nogap_peak_ms_20ms",
    "n2_nogap_peak_ms_50ms",
    "n1p2_gap_no_gap_ratio_20ms",
    "n1p2_gap_no_gap_ratio_50ms",
    "PeakF_Theta_20ms",
    "PeakF_Theta_50ms",
    "SpectralEdge_Delta_20ms",
    "SpectralEdge_Delta_50ms",
    "RelativeAlpha_20ms",
    "RelativeAlpha_50ms",
    "DTABR_20ms",
    "DTABR_50ms"]

print(len(list_of_feat))
# Out:
# 31

# %%
print(list_of_feat)
# Out:
# ['Subjects', 'p3_gap_peak_amp_20ms', 'p3_gap_peak_amp_50ms', 'p1_gap_peak_amp_20ms', 'p1_gap_peak_amp_50ms', 'gap_AUC_n1p2_R_20ms', 'gap_AUC_n1p2_R_50ms', 'n1p3_interval_nogap_20ms', 'n1p3_interval_nogap_50ms', 'n2_gap_peak_amp_20ms', 'n2_gap_peak_amp_50ms', 'p2n2_gap_nogap_diff_20ms', 'p2n2_gap_nogap_diff_50ms', 'gap_AUC_n1p2_L_20ms', 'gap_AUC_n1p2_L_50ms', 'gap_AUC_p1n1_R_20ms', 'gap_AUC_p1n1_R_50ms', 'gap_AUC_n1p2n2_20ms', 'gap_AUC_n1p2n2_50ms', 'n2_nogap_peak_ms_20ms', 'n2_nogap_peak_ms_50ms', 'n1p2_gap_no_gap_ratio_20ms', 'n1p2_gap_no_gap_ratio_50ms', 'PeakF_Theta_20ms', 'PeakF_Theta_50ms', 'SpectralEdge_Delta_20ms', 'SpectralEdge_Delta_50ms', 'RelativeAlpha_20ms', 'RelativeAlpha_50ms', 'DTABR_20ms', 'DTABR_50ms']

# %%
X_new = dataset[list_of_feat]
y_new = dataset.iloc[:, 1]

# %%
X_new.shape
# Out:
# (165, 31)

# %%
y_new.shape
# Out:
# (165,)

# %%
'''from sklearn.model_selection import train_test_split
X_train_with_subject, X_test_with_subject, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.10655737705, random_state = 0)'''
# Out:
# 'from sklearn.model_selection import train_test_split\nX_train_with_subject, X_test_with_subject, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.10655737705, random_state = 0)'

# %%
X_train_with_subject=X_new.iloc[:108,:]  
X_test_with_subject=X_new.iloc[108:,:]
y_train=y_new.iloc[:108]
y_test=y_new.iloc[108:]

# %%
X_train_with_subject
# Out:
#                   Subjects  p3_gap_peak_amp_20ms  p3_gap_peak_amp_50ms  \
# 0           '06_HSO_60_01'             10.092901             10.988888
# 1           '06_LSR_34_01'             17.845904             11.594803
# 2           '07_KHJ_33_02'              5.955162              6.788743
# 3           '08_LJS_26_01'              5.638387              7.702433
# 4           '09_JBH_58_01'             13.384259             11.459661
# ..                     ...                   ...                   ...
# 103      '37_JTH_54_01_8k'              6.233526              6.487803
# 104      '38_KSP_55_01_8k'              7.242361              9.821408
# 105      '39_PYH_68_01_4k'              9.044319              8.014453
# 106      '41_HKS_65_01_8k'              3.738782              7.349214
# 107      '43_PMH_64_01_8k'              4.676798              2.315542
#
#      p1_gap_peak_amp_20ms  p1_gap_peak_amp_50ms  gap_AUC_n1p2_R_20ms  \
# 0               10.379415              8.422405             0.108394
# 1               16.052158              9.174875             0.147754
# 2                3.959968              5.523335             0.264380
# 3                3.270295              7.462832             0.183007
# 4               10.114451             12.183127             0.123296
# ..                    ...                   ...                  ...
# 103              4.007776              4.681958             0.130233
# 104              2.857598              4.063369             0.557335
# 105              2.595737              2.521545             0.353462
# 106              4.770803              4.101451             0.197828
# 107              3.800128              4.082925             0.678626
#
#      gap_AUC_n1p2_R_50ms  n1p3_interval_nogap_20ms  n1p3_interval_nogap_50ms  \
# 0               0.229010                  6.555694                  4.761199
# 1               0.185048                 11.405960                  5.217714
# 2               0.073321                  5.046243                  4.065167
# 3               0.226157                  2.104986                  3.049172
# 4               0.118154                  8.523228                  7.317047
# ..                   ...                       ...                       ...
# 103             0.214191                  4.614487                  3.456188
# 104             0.526057                  5.601528                  6.814410
# 105             0.475860                  4.941975                  6.062910
# 106             0.197740                  4.131827                  3.889128
# 107             0.786799                  4.482163                  2.820126
#
#      n2_gap_peak_amp_20ms  ...  n1p2_gap_no_gap_ratio_20ms  \
# 0               11.544318  ...                 -601.061131
# 1               17.548932  ...                 -737.699525
# 2                6.958529  ...                 -286.287981
# 3                2.438374  ...                  -72.540051
# 4               11.947191  ...                 -432.078750
# ..                    ...  ...                         ...
# 103              5.905573  ...                 -242.763418
# 104              8.033632  ...                 -359.196223
# 105              6.310380  ...                 -146.641295
# 106              5.224312  ...                 -378.315377
# 107              5.065157  ...                 -493.796760
#
#      n1p2_gap_no_gap_ratio_50ms  PeakF_Theta_20ms  PeakF_Theta_50ms  \
# 0                   -526.598962          3.891052          3.891052
# 1                   -507.540090          3.891052          3.891052
# 2                   -520.355648          4.280156          5.058368
# 3                   -158.422926          3.891052          3.501946
# 4                   -227.072483          4.280156          3.891052
# ..                          ...               ...               ...
# 103                 -252.384700          3.501946          5.058368
# 104                 -327.087214          4.669262          4.669262
# 105                 -301.179802         21.400778          4.669262
# 106                 -223.812815          3.501946          4.280156
# 107                 -263.291677          3.501946          4.280156
#
#      SpectralEdge_Delta_20ms  SpectralEdge_Delta_50ms  RelativeAlpha_20ms  \
# 0                   4.280156                 4.280156              0.0887
# 1                   4.280156                 4.280156              0.0864
# 2                   4.669262                 4.669262              0.0783
# 3                   3.891050                 4.280156              0.1110
# 4                   3.891050                 4.280156              0.1230
# ..                       ...                      ...                 ...
# 103                 5.058368                 4.280156              0.1830
# 104                 5.058368                 4.669262              0.1480
# 105                 5.058368                 4.669262              0.2820
# 106                 4.280156                 4.669260              0.1520
# 107                 4.280156                 4.669260              0.1520
#
#      RelativeAlpha_50ms  DTABR_20ms  DTABR_50ms
# 0                0.0949        6.64        6.57
# 1                0.1210        7.06        4.83
# 2                0.0805        6.57        6.51
# 3                0.0885        5.16        6.80
# 4                0.1090        4.35        5.04
# ..                  ...         ...         ...
# 103              0.1480        2.34        2.85
# 104              0.1630        3.62        2.33
# 105              0.1630        1.41        2.33
# 106              0.1520        2.29        2.01
# 107              0.1520        2.29        2.01
#
# [108 rows x 31 columns]

# %%
X_test_with_subject
# Out:
#                   Subjects  p3_gap_peak_amp_20ms  p3_gap_peak_amp_50ms  \
# 108      '44_KMR_59_01_4k'              3.517800              7.405892
# 109      '45_JGB_58_01_8k'              6.139246              5.880981
# 110      '46_HCN_59_01_8k'              6.126890              4.604948
# 111      '47_KCH_60_01_8k'              6.487341              7.726059
# 112      '48_KYH_52_01_8k'             14.904677              9.868674
# 113      '50_PSD_53_01_8k'              6.954890              3.277235
# 114      '52_KHM_47_01_4k'              5.175671              8.228541
# 115      '53_JWJ_20_01_8k'              4.138365              5.831637
# 116      '54_LJB_26_01_8k'              6.818168              6.948500
# 117      '56_LJN_55_01_8k'              8.574069              8.542279
# 118      '59_LDI_60_01_4k'             13.062522             15.902733
# 119      '60_KYJ_61_01_8k'              9.334810              5.107648
# 120      '61_KSS_58_01_8k'              5.880235              6.323057
# 121      '62_KJW_57_01_8k'              8.422721              5.966055
# 122      '64_SYT_51_01_8k'              4.978698              4.290480
# 123      '66_MGH_52_01_8k'              5.625449              8.530195
# 124      '67_KJS_62_01_8k'             10.641949              9.634835
# 125      '68_PJS_62_01_8k'              2.687787              2.975237
# 126      '69_KTS_55_01_4k'              8.148390              6.811314
# 127      '70_LSM_47_01_8k'              4.776646              7.310949
# 141              0.1810       2.110        1.69
# 142              0.1410       3.130        2.84
# 143              0.1740       1.530        1.68
# 144              0.1190       3.450        4.74
# 145              0.1510       3.420        2.20
# 146              0.1940       2.030        1.65
# 147              0.1520       3.970        2.84
# 148              0.1390       5.370        2.98
# 149              0.2050       1.150        1.53
# 150              0.1460       1.420        3.34
# 151              0.1520       1.150        2.67
# 152              0.1250       1.780        3.54
# 153              0.1080       5.800        5.59
# 154              0.1080       2.530        4.19
# 155              0.1830       1.640        2.33
# 156              0.1620       2.950        2.72
# 157              0.0902       2.990        6.92
# 158              0.0649      12.300        9.90
# 159              0.1050       7.210        5.74
# 160              0.1340       2.850        3.56
# 161              0.1910       1.070        1.64
# 162              0.1850       1.280        1.97
# 163              0.1790       2.320        2.61
# 164              0.2150       2.130        1.48
#
# [57 rows x 31 columns]

# %%
X_train = X_train_with_subject.iloc[:,1:]
X_test  = X_test_with_subject.iloc[:,1:]

# %%
result={}

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_defult = AdaBoostClassifier(random_state=0)
ada_defult.fit(X_train, y_train)
y_pred = ada_defult.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(ada_defult,1,'AdaBoostClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[13  6]
#  [18 20]]
#               precision    recall  f1-score   support
#
#            0       0.42      0.68      0.52        19
#            1       0.77      0.53      0.62        38
#
#     accuracy                           0.58        57
#    macro avg       0.59      0.61      0.57        57
# weighted avg       0.65      0.58      0.59        57
#
# Accurecy:  0.5789473684210527

# %%
from sklearn.ensemble import AdaBoostClassifier
N=200
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = AdaBoostClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt
#plot the relationship between K and the testing accuracy
plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/200 round completed......................... Accurecy: 0.5964912280701754
# 2/200 round completed......................... Accurecy: 0.5087719298245614
# 3/200 round completed......................... Accurecy: 0.631578947368421
# 4/200 round completed......................... Accurecy: 0.631578947368421
# 5/200 round completed......................... Accurecy: 0.6140350877192983
# 6/200 round completed......................... Accurecy: 0.6666666666666666
# 7/200 round completed......................... Accurecy: 0.6666666666666666
# 8/200 round completed......................... Accurecy: 0.6842105263157895
# 9/200 round completed......................... Accurecy: 0.6666666666666666
# 10/200 round completed......................... Accurecy: 0.6140350877192983
# 11/200 round completed......................... Accurecy: 0.631578947368421
# 12/200 round completed......................... Accurecy: 0.5964912280701754
# 13/200 round completed......................... Accurecy: 0.6140350877192983
# 14/200 round completed......................... Accurecy: 0.5614035087719298
# 15/200 round completed......................... Accurecy: 0.6140350877192983
# 16/200 round completed......................... Accurecy: 0.6140350877192983
# 17/200 round completed......................... Accurecy: 0.631578947368421
# 18/200 round completed......................... Accurecy: 0.6140350877192983
# 19/200 round completed......................... Accurecy: 0.5964912280701754
# 20/200 round completed......................... Accurecy: 0.5263157894736842
# 21/200 round completed......................... Accurecy: 0.5964912280701754
# 22/200 round completed......................... Accurecy: 0.5964912280701754
# 23/200 round completed......................... Accurecy: 0.5789473684210527
# 24/200 round completed......................... Accurecy: 0.5964912280701754
# 25/200 round completed......................... Accurecy: 0.5789473684210527
# 26/200 round completed......................... Accurecy: 0.6140350877192983
# 27/200 round completed......................... Accurecy: 0.5964912280701754
# 193/200 round completed......................... Accurecy: 0.6666666666666666
# 194/200 round completed......................... Accurecy: 0.6666666666666666
# 195/200 round completed......................... Accurecy: 0.6666666666666666
# 196/200 round completed......................... Accurecy: 0.6491228070175439
# 197/200 round completed......................... Accurecy: 0.6491228070175439
# 198/200 round completed......................... Accurecy: 0.6491228070175439
# 199/200 round completed......................... Accurecy: 0.6491228070175439
# 200/200 round completed......................... Accurecy: 0.631578947368421
# The best n_estimators:
# 8

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_best_estimator = AdaBoostClassifier(n_estimators=best_estimator,random_state=0)
ada_best_estimator.fit(X_train, y_train)
y_pred = ada_best_estimator.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(ada_best_estimator,1,'AdaBoostClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[12  7]
#  [11 27]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.63      0.57        19
#            1       0.79      0.71      0.75        38
#
#     accuracy                           0.68        57
#    macro avg       0.66      0.67      0.66        57
# weighted avg       0.70      0.68      0.69        57
#
# Accurecy:  0.6842105263157895

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Graddient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold

gradBoost_default = GradientBoostingClassifier(random_state=0)
gradBoost_default.fit(X_train, y_train)
y_pred = gradBoost_default.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(gradBoost_default,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[13  6]
#  [14 24]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.68      0.57        19
#            1       0.80      0.63      0.71        38
#
#     accuracy                           0.65        57
#    macro avg       0.64      0.66      0.64        57
# weighted avg       0.69      0.65      0.66        57
#
# Accurecy:  0.6491228070175439

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = GradientBoostingClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/150 round completed......................... Accurecy: 0.3333333333333333
# 2/150 round completed......................... Accurecy: 0.3333333333333333
# 3/150 round completed......................... Accurecy: 0.5789473684210527
# 4/150 round completed......................... Accurecy: 0.5789473684210527
# 5/150 round completed......................... Accurecy: 0.5964912280701754
# 6/150 round completed......................... Accurecy: 0.631578947368421
# 7/150 round completed......................... Accurecy: 0.5964912280701754
# 8/150 round completed......................... Accurecy: 0.631578947368421
# 9/150 round completed......................... Accurecy: 0.6491228070175439
# 10/150 round completed......................... Accurecy: 0.6491228070175439
# 11/150 round completed......................... Accurecy: 0.6491228070175439
# 12/150 round completed......................... Accurecy: 0.6491228070175439
# 13/150 round completed......................... Accurecy: 0.6491228070175439
# 14/150 round completed......................... Accurecy: 0.6666666666666666
# 15/150 round completed......................... Accurecy: 0.6491228070175439
# 16/150 round completed......................... Accurecy: 0.6491228070175439
# 17/150 round completed......................... Accurecy: 0.6491228070175439
# 18/150 round completed......................... Accurecy: 0.6491228070175439
# 19/150 round completed......................... Accurecy: 0.6491228070175439
# 20/150 round completed......................... Accurecy: 0.6666666666666666
# 21/150 round completed......................... Accurecy: 0.6491228070175439
# 22/150 round completed......................... Accurecy: 0.6666666666666666
# 23/150 round completed......................... Accurecy: 0.6666666666666666
# 24/150 round completed......................... Accurecy: 0.6666666666666666
# 25/150 round completed......................... Accurecy: 0.6666666666666666
# 26/150 round completed......................... Accurecy: 0.6842105263157895
# 27/150 round completed......................... Accurecy: 0.6842105263157895
# 28/150 round completed......................... Accurecy: 0.6842105263157895
# 29/150 round completed......................... Accurecy: 0.6842105263157895
# 30/150 round completed......................... Accurecy: 0.6842105263157895
# 141/150 round completed......................... Accurecy: 0.631578947368421
# 142/150 round completed......................... Accurecy: 0.631578947368421
# 143/150 round completed......................... Accurecy: 0.631578947368421
# 144/150 round completed......................... Accurecy: 0.631578947368421
# 145/150 round completed......................... Accurecy: 0.631578947368421
# 146/150 round completed......................... Accurecy: 0.631578947368421
# 147/150 round completed......................... Accurecy: 0.631578947368421
# 148/150 round completed......................... Accurecy: 0.631578947368421
# 149/150 round completed......................... Accurecy: 0.631578947368421
# 150/150 round completed......................... Accurecy: 0.631578947368421
# The best n_estimators:
# 69

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
N=30
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = GradientBoostingClassifier(max_depth=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best Depth:")
best_depth=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_depth)
# Out:
# 1/30 round completed......................... Accurecy: 0.7368421052631579
# 2/30 round completed......................... Accurecy: 0.631578947368421
# 3/30 round completed......................... Accurecy: 0.6491228070175439
# 4/30 round completed......................... Accurecy: 0.6140350877192983
# 5/30 round completed......................... Accurecy: 0.5614035087719298
# 6/30 round completed......................... Accurecy: 0.5263157894736842
# 7/30 round completed......................... Accurecy: 0.6140350877192983
# 8/30 round completed......................... Accurecy: 0.631578947368421
# 9/30 round completed......................... Accurecy: 0.631578947368421
# 10/30 round completed......................... Accurecy: 0.631578947368421
# 11/30 round completed......................... Accurecy: 0.631578947368421
# 12/30 round completed......................... Accurecy: 0.631578947368421
# 13/30 round completed......................... Accurecy: 0.631578947368421
# 14/30 round completed......................... Accurecy: 0.631578947368421
# 15/30 round completed......................... Accurecy: 0.631578947368421
# 16/30 round completed......................... Accurecy: 0.631578947368421
# 17/30 round completed......................... Accurecy: 0.631578947368421
# 18/30 round completed......................... Accurecy: 0.631578947368421
# 19/30 round completed......................... Accurecy: 0.631578947368421
# 20/30 round completed......................... Accurecy: 0.631578947368421
# 21/30 round completed......................... Accurecy: 0.631578947368421
# 22/30 round completed......................... Accurecy: 0.631578947368421
# 23/30 round completed......................... Accurecy: 0.631578947368421
# 24/30 round completed......................... Accurecy: 0.631578947368421
# 25/30 round completed......................... Accurecy: 0.631578947368421
# 26/30 round completed......................... Accurecy: 0.631578947368421
# 27/30 round completed......................... Accurecy: 0.631578947368421
# 28/30 round completed......................... Accurecy: 0.631578947368421
# 29/30 round completed......................... Accurecy: 0.631578947368421
# 30/30 round completed......................... Accurecy: 0.631578947368421
# The best Depth:
# 1

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_estimator = GradientBoostingClassifier(n_estimators=best_estimator,random_state=0)
gradBoost_estimator.fit(X_train, y_train)
y_pred = gradBoost_estimator.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(gradBoost_estimator,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  4]
#  [13 25]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64        19
#            1       0.86      0.66      0.75        38
#
#     accuracy                           0.70        57
#    macro avg       0.70      0.72      0.69        57
# weighted avg       0.75      0.70      0.71        57
#
# Accurecy:  0.7017543859649122

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_depth = GradientBoostingClassifier(max_depth=best_depth,random_state=0)
gradBoost_depth.fit(X_train, y_train)
y_pred = gradBoost_depth.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))

result[(gradBoost_depth,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[17  2]
#  [13 25]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.89      0.69        19
#            1       0.93      0.66      0.77        38
#
#     accuracy                           0.74        57
#    macro avg       0.75      0.78      0.73        57
# weighted avg       0.81      0.74      0.74        57
#
# Accurecy:  0.7368421052631579

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradBoost_all = GradientBoostingClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
gradBoost_all.fit(X_train, y_train)
y_pred = gradBoost_all.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))

result[(gradBoost_all,2,'GradientBoostingClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[16  3]
#  [16 22]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.84      0.63        19
#            1       0.88      0.58      0.70        38
#
#     accuracy                           0.67        57
#    macro avg       0.69      0.71      0.66        57
# weighted avg       0.75      0.67      0.67        57
#
# Accurecy:  0.6666666666666666

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_default = RandomForestClassifier(random_state=0)
rf_default.fit(X_train, y_train)
y_pred=rf_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_default,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[14  5]
#  [18 20]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.74      0.55        19
#            1       0.80      0.53      0.63        38
#
#     accuracy                           0.60        57
#    macro avg       0.62      0.63      0.59        57
# weighted avg       0.68      0.60      0.61        57
#
# Accurecy:  0.5964912280701754

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
N=150
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  classifier = RandomForestClassifier(n_estimators=k,random_state=0)
  classifier.fit(X_train, y_train)
  y_pred=classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))



# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/150 round completed......................... Accurecy: 0.5964912280701754
# 2/150 round completed......................... Accurecy: 0.5964912280701754
# 3/150 round completed......................... Accurecy: 0.6666666666666666
# 4/150 round completed......................... Accurecy: 0.5964912280701754
# 5/150 round completed......................... Accurecy: 0.6666666666666666
# 6/150 round completed......................... Accurecy: 0.6491228070175439
# 7/150 round completed......................... Accurecy: 0.6491228070175439
# 8/150 round completed......................... Accurecy: 0.5964912280701754
# 9/150 round completed......................... Accurecy: 0.6140350877192983
# 10/150 round completed......................... Accurecy: 0.631578947368421
# 11/150 round completed......................... Accurecy: 0.631578947368421
# 12/150 round completed......................... Accurecy: 0.631578947368421
# 13/150 round completed......................... Accurecy: 0.631578947368421
# 14/150 round completed......................... Accurecy: 0.631578947368421
# 15/150 round completed......................... Accurecy: 0.6491228070175439
# 16/150 round completed......................... Accurecy: 0.5964912280701754
# 17/150 round completed......................... Accurecy: 0.6491228070175439
# 18/150 round completed......................... Accurecy: 0.631578947368421
# 19/150 round completed......................... Accurecy: 0.6666666666666666
# 20/150 round completed......................... Accurecy: 0.631578947368421
# 21/150 round completed......................... Accurecy: 0.6491228070175439
# 22/150 round completed......................... Accurecy: 0.6140350877192983
# 23/150 round completed......................... Accurecy: 0.631578947368421
# 24/150 round completed......................... Accurecy: 0.5789473684210527
# 25/150 round completed......................... Accurecy: 0.6140350877192983
# 26/150 round completed......................... Accurecy: 0.6140350877192983
# 27/150 round completed......................... Accurecy: 0.6491228070175439
# 28/150 round completed......................... Accurecy: 0.631578947368421
# 29/150 round completed......................... Accurecy: 0.6491228070175439
# 30/150 round completed......................... Accurecy: 0.6491228070175439
# 31/150 round completed......................... Accurecy: 0.6491228070175439
# 32/150 round completed......................... Accurecy: 0.6491228070175439
# 33/150 round completed......................... Accurecy: 0.6666666666666666
# 34/150 round completed......................... Accurecy: 0.631578947368421
# 35/150 round completed......................... Accurecy: 0.6491228070175439
# 36/150 round completed......................... Accurecy: 0.631578947368421
# 37/150 round completed......................... Accurecy: 0.6491228070175439
# 38/150 round completed......................... Accurecy: 0.631578947368421
# 39/150 round completed......................... Accurecy: 0.631578947368421
# 40/150 round completed......................... Accurecy: 0.631578947368421
# 41/150 round completed......................... Accurecy: 0.631578947368421
# 42/150 round completed......................... Accurecy: 0.631578947368421
# 111/150 round completed......................... Accurecy: 0.5964912280701754
# 112/150 round completed......................... Accurecy: 0.5964912280701754
# 113/150 round completed......................... Accurecy: 0.5964912280701754
# 114/150 round completed......................... Accurecy: 0.5964912280701754
# 115/150 round completed......................... Accurecy: 0.5964912280701754
# 116/150 round completed......................... Accurecy: 0.5964912280701754
# 117/150 round completed......................... Accurecy: 0.5964912280701754
# 118/150 round completed......................... Accurecy: 0.5964912280701754
# 119/150 round completed......................... Accurecy: 0.5964912280701754
# 120/150 round completed......................... Accurecy: 0.5964912280701754
# 121/150 round completed......................... Accurecy: 0.5964912280701754
# 122/150 round completed......................... Accurecy: 0.5964912280701754
# 123/150 round completed......................... Accurecy: 0.5964912280701754
# 124/150 round completed......................... Accurecy: 0.5964912280701754
# 125/150 round completed......................... Accurecy: 0.5964912280701754
# 126/150 round completed......................... Accurecy: 0.5964912280701754
# 127/150 round completed......................... Accurecy: 0.5964912280701754
# 128/150 round completed......................... Accurecy: 0.5964912280701754
# 129/150 round completed......................... Accurecy: 0.5964912280701754
# 130/150 round completed......................... Accurecy: 0.5964912280701754
# 131/150 round completed......................... Accurecy: 0.5964912280701754
# 132/150 round completed......................... Accurecy: 0.5964912280701754
# 133/150 round completed......................... Accurecy: 0.5964912280701754
# 134/150 round completed......................... Accurecy: 0.5964912280701754
# 135/150 round completed......................... Accurecy: 0.5964912280701754
# 136/150 round completed......................... Accurecy: 0.5964912280701754
# 137/150 round completed......................... Accurecy: 0.5964912280701754
# 138/150 round completed......................... Accurecy: 0.5964912280701754
# 139/150 round completed......................... Accurecy: 0.5964912280701754
# 140/150 round completed......................... Accurecy: 0.5964912280701754
# 141/150 round completed......................... Accurecy: 0.5964912280701754
# 142/150 round completed......................... Accurecy: 0.5964912280701754
# 143/150 round completed......................... Accurecy: 0.5964912280701754
# 144/150 round completed......................... Accurecy: 0.5964912280701754
# 145/150 round completed......................... Accurecy: 0.5964912280701754
# 146/150 round completed......................... Accurecy: 0.5964912280701754
# 147/150 round completed......................... Accurecy: 0.5964912280701754
# 148/150 round completed......................... Accurecy: 0.5964912280701754
# 149/150 round completed......................... Accurecy: 0.5964912280701754
# 150/150 round completed......................... Accurecy: 0.5964912280701754
# The best Depth:
# 2

# %%
from sklearn.ensemble import RandomForestClassifier
rf_estimator = RandomForestClassifier(n_estimators=best_estimator,random_state=0)
rf_estimator.fit(X_train, y_train)
y_pred=rf_estimator.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_estimator,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  4]
#  [15 23]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.79      0.61        19
#            1       0.85      0.61      0.71        38
#
#     accuracy                           0.67        57
#    macro avg       0.68      0.70      0.66        57
# weighted avg       0.73      0.67      0.68        57
#
# Accurecy:  0.6666666666666666

# %%
from sklearn.ensemble import RandomForestClassifier
rf_depth = RandomForestClassifier(max_depth=best_depth,random_state=0)
rf_depth.fit(X_train, y_train)
y_pred=rf_depth.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_depth,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  4]
#  [19 19]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.79      0.57        19
#            1       0.83      0.50      0.62        38
#
#     accuracy                           0.60        57
#    macro avg       0.63      0.64      0.59        57
# weighted avg       0.70      0.60      0.60        57
#
# Accurecy:  0.5964912280701754

# %%
from sklearn.ensemble import RandomForestClassifier
rf_all = RandomForestClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
rf_all.fit(X_train, y_train)
y_pred=rf_all.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(rf_all,3,'RandomForestClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[17  2]
#  [24 14]]
#               precision    recall  f1-score   support
#
#            0       0.41      0.89      0.57        19
#            1       0.88      0.37      0.52        38
#
#     accuracy                           0.54        57
#    macro avg       0.64      0.63      0.54        57
# weighted avg       0.72      0.54      0.53        57
#
# Accurecy:  0.543859649122807

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #XGB

# %%
import xgboost as xgb
xgb_deafult = xgb.XGBClassifier(random_state=0)
xgb_deafult.fit(X_train,y_train)
y_pred = xgb_deafult.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_deafult,4,'xgboost')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  4]
#  [15 23]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.79      0.61        19
#            1       0.85      0.61      0.71        38
#
#     accuracy                           0.67        57
#    macro avg       0.68      0.70      0.66        57
# weighted avg       0.73      0.67      0.68        57
#
# Accurecy:  0.6666666666666666

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score
N=250
k_range = range (1,N+1)
scores={}
scores_list = []
for k in k_range:
  xgb_classifier = xgb.XGBClassifier(n_estimators=k,random_state=0)
  xgb_classifier.fit(X_train, y_train)
  y_pred=xgb_classifier.predict(X_test)
  scores[k] = accuracy_score(y_test,y_pred)
  scores_list.append(accuracy_score(y_test,y_pred))
  print(str(k)+"/"+str(N)+" round completed......................... Accurecy: "+str(accuracy_score(y_test,y_pred)))


# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (25,10))
plt.plot(k_range,scores_list)
plt.xlabel('Value of n_estimators')
plt.ylabel ('Testing Accuracy')



print("The best n_estimators:")
best_estimator=list(scores.keys())[scores_list.index(max(scores_list))]
print(best_estimator)
# Out:
# 1/250 round completed......................... Accurecy: 0.631578947368421
# 2/250 round completed......................... Accurecy: 0.6666666666666666
# 3/250 round completed......................... Accurecy: 0.6666666666666666
# 4/250 round completed......................... Accurecy: 0.6666666666666666
# 5/250 round completed......................... Accurecy: 0.6666666666666666
# 6/250 round completed......................... Accurecy: 0.6666666666666666
# 7/250 round completed......................... Accurecy: 0.6491228070175439
# 8/250 round completed......................... Accurecy: 0.6491228070175439
# 9/250 round completed......................... Accurecy: 0.631578947368421
# 10/250 round completed......................... Accurecy: 0.631578947368421
# 11/250 round completed......................... Accurecy: 0.6140350877192983
# 12/250 round completed......................... Accurecy: 0.6140350877192983
# 13/250 round completed......................... Accurecy: 0.6140350877192983
# 14/250 round completed......................... Accurecy: 0.5964912280701754
# 15/250 round completed......................... Accurecy: 0.631578947368421
# 16/250 round completed......................... Accurecy: 0.6491228070175439
# 17/250 round completed......................... Accurecy: 0.6491228070175439
# 18/250 round completed......................... Accurecy: 0.6491228070175439
# 19/250 round completed......................... Accurecy: 0.6491228070175439
# 20/250 round completed......................... Accurecy: 0.6491228070175439
# 21/250 round completed......................... Accurecy: 0.6491228070175439
# 22/250 round completed......................... Accurecy: 0.6491228070175439
# 23/250 round completed......................... Accurecy: 0.6666666666666666
# 24/250 round completed......................... Accurecy: 0.6666666666666666
# 25/250 round completed......................... Accurecy: 0.6666666666666666
# 26/250 round completed......................... Accurecy: 0.6666666666666666
# 27/250 round completed......................... Accurecy: 0.6666666666666666
# 28/250 round completed......................... Accurecy: 0.6666666666666666
# 29/250 round completed......................... Accurecy: 0.6666666666666666
# 30/250 round completed......................... Accurecy: 0.6842105263157895
# 31/250 round completed......................... Accurecy: 0.6842105263157895
# 32/250 round completed......................... Accurecy: 0.6666666666666666
# 33/250 round completed......................... Accurecy: 0.6666666666666666
# 34/250 round completed......................... Accurecy: 0.7017543859649122
# 35/250 round completed......................... Accurecy: 0.6842105263157895
# 36/250 round completed......................... Accurecy: 0.7017543859649122
# 37/250 round completed......................... Accurecy: 0.6842105263157895
# 232/250 round completed......................... Accurecy: 0.631578947368421
# 233/250 round completed......................... Accurecy: 0.631578947368421
# 234/250 round completed......................... Accurecy: 0.631578947368421
# 235/250 round completed......................... Accurecy: 0.631578947368421
# 236/250 round completed......................... Accurecy: 0.631578947368421
# 237/250 round completed......................... Accurecy: 0.631578947368421
# 238/250 round completed......................... Accurecy: 0.631578947368421
# 239/250 round completed......................... Accurecy: 0.631578947368421
# 240/250 round completed......................... Accurecy: 0.631578947368421
# 241/250 round completed......................... Accurecy: 0.631578947368421
# 242/250 round completed......................... Accurecy: 0.631578947368421
# 243/250 round completed......................... Accurecy: 0.631578947368421
# 244/250 round completed......................... Accurecy: 0.631578947368421
# 245/250 round completed......................... Accurecy: 0.631578947368421
# 246/250 round completed......................... Accurecy: 0.631578947368421
# 247/250 round completed......................... Accurecy: 0.631578947368421
# 248/250 round completed......................... Accurecy: 0.631578947368421
# 249/250 round completed......................... Accurecy: 0.631578947368421
# 250/250 round completed......................... Accurecy: 0.631578947368421
# The best depth:
# 1

# %%
import xgboost as xgb
xgb_depth = xgb.XGBClassifier(max_depth=best_depth,random_state=0)
xgb_depth.fit(X_train,y_train)
y_pred = xgb_depth.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_depth,4,'xgboost')]=accuracy_score(y_test, y_pred)
print(xgb_depth)
# Out:
# [[16  3]
#  [13 25]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.84      0.67        19
#            1       0.89      0.66      0.76        38
#
#     accuracy                           0.72        57
#    macro avg       0.72      0.75      0.71        57
# weighted avg       0.78      0.72      0.73        57
#
# Accurecy:  0.7192982456140351
# XGBClassifier(max_depth=1)

# %%
import xgboost as xgb
xgb_estimator = xgb.XGBClassifier(n_estimators=best_estimator,random_state=0)
xgb_estimator.fit(X_train,y_train)
y_pred = xgb_estimator.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_estimator,4,'xgboost')]=accuracy_score(y_test, y_pred)
print(xgb_estimator)
# Out:
# [[15  4]
#  [13 25]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64        19
#            1       0.86      0.66      0.75        38
#
#     accuracy                           0.70        57
#    macro avg       0.70      0.72      0.69        57
# weighted avg       0.75      0.70      0.71        57
#
# Accurecy:  0.7017543859649122
# XGBClassifier(n_estimators=34)

# %%
import xgboost as xgb
xgb_all = xgb.XGBClassifier(n_estimators=best_estimator,max_depth=best_depth,random_state=0)
xgb_all.fit(X_train,y_train)
y_pred = xgb_all.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(xgb_all,4,'xgboost')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  4]
#  [20 18]]
#               precision    recall  f1-score   support
#
#            0       0.43      0.79      0.56        19
#            1       0.82      0.47      0.60        38
#
#     accuracy                           0.58        57
#    macro avg       0.62      0.63      0.58        57
# weighted avg       0.69      0.58      0.59        57
#
# Accurecy:  0.5789473684210527

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_default = KNeighborsClassifier()
knn_default.fit(X_train, y_train)
y_pred=knn_default.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(knn_default,5,'KNeighborsClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[14  5]
#  [31  7]]
#               precision    recall  f1-score   support
#
#            0       0.31      0.74      0.44        19
#            1       0.58      0.18      0.28        38
#
#     accuracy                           0.37        57
#    macro avg       0.45      0.46      0.36        57
# weighted avg       0.49      0.37      0.33        57
#
# Accurecy:  0.3684210526315789

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# %%
from sklearn.neighbors import KNeighborsClassifier
knn_neighbors = KNeighborsClassifier(n_neighbors=best)
knn_neighbors.fit(X_train, y_train)
y_pred=knn_neighbors.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(knn_neighbors,5,'KNeighborsClassifier')]=accuracy_score(y_test, y_pred)
# Out:
# [[15  4]
#  [25 13]]
#               precision    recall  f1-score   support
#
#            0       0.38      0.79      0.51        19
#            1       0.76      0.34      0.47        38
#
#     accuracy                           0.49        57
#    macro avg       0.57      0.57      0.49        57
# weighted avg       0.63      0.49      0.48        57
#
# Accurecy:  0.49122807017543857

# %% [markdown]
# #NB

# %%
from sklearn.naive_bayes import GaussianNB

nb_deafult = GaussianNB()
nb_deafult.fit(X_train, y_train)
y_pred = nb_deafult.predict(X_test)


from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
print("Accurecy: ",accuracy_score(y_test, y_pred))
result[(nb_deafult,6,'GaussianNB')]=accuracy_score(y_test, y_pred)
# Out:
# [[12  7]
#  [12 26]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.63      0.56        19
#            1       0.79      0.68      0.73        38
#
#     accuracy                           0.67        57
#    macro avg       0.64      0.66      0.65        57
# weighted avg       0.69      0.67      0.67        57
#
# Accurecy:  0.6666666666666666

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #ANN

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(250, input_shape=(30,), activation='relu'), # input laye
    keras.layers.Dense(150, activation='sigmoid'),
    keras.layers.Dense(75, activation='softmax')                    # output layer
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=200)

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 7ms/step - loss: 4.1564 - accuracy: 0.0278
# Epoch 2/200
# 4/4 [==============================] - 0s 4ms/step - loss: 2.9251 - accuracy: 0.3796
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1778 - accuracy: 0.3796
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6711 - accuracy: 0.3796
# Epoch 5/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3541 - accuracy: 0.3796
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1053 - accuracy: 0.4167
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9212 - accuracy: 0.5463
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8075 - accuracy: 0.6481
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7556 - accuracy: 0.6759
# Epoch 10/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7208 - accuracy: 0.6574
# Epoch 11/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7089 - accuracy: 0.6481
# Epoch 12/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6961 - accuracy: 0.6481
# Epoch 13/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6719 - accuracy: 0.6759
# Epoch 14/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6838 - accuracy: 0.6944
# Epoch 15/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6787 - accuracy: 0.6852
# Epoch 16/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6716 - accuracy: 0.6667
# Epoch 17/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6673 - accuracy: 0.6574
# Epoch 18/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6620 - accuracy: 0.6481
# Epoch 19/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6610 - accuracy: 0.6481
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.6574
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6560 - accuracy: 0.6667
# Epoch 22/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6523 - accuracy: 0.6667
# Epoch 23/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6423 - accuracy: 0.6852
# Epoch 24/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6351 - accuracy: 0.7315
# Epoch 25/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6318 - accuracy: 0.6852
# Epoch 26/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6399 - accuracy: 0.6574
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6508 - accuracy: 0.6667
# Epoch 28/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6435 - accuracy: 0.6667
# Epoch 29/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6464 - accuracy: 0.6574
# Epoch 30/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6515 - accuracy: 0.6481
# Epoch 31/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6507 - accuracy: 0.6481
# Epoch 32/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6443 - accuracy: 0.6481
# Epoch 33/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6448 - accuracy: 0.6481
# Epoch 34/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6444 - accuracy: 0.6389
# Epoch 35/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.6481
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6420 - accuracy: 0.6481
# Epoch 37/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6478 - accuracy: 0.6389
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6436 - accuracy: 0.6574
# Epoch 39/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6420 - accuracy: 0.6667
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6436 - accuracy: 0.6667
# Epoch 41/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6372 - accuracy: 0.6574
# Epoch 42/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.6481
# Epoch 43/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6263 - accuracy: 0.6574
# Epoch 44/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.6667
# Epoch 45/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6443 - accuracy: 0.6667
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6407 - accuracy: 0.6667
# Epoch 47/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6389 - accuracy: 0.6481
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6387 - accuracy: 0.6481
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6395 - accuracy: 0.6481
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6481
# Epoch 51/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6395 - accuracy: 0.6667
# Epoch 52/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6368 - accuracy: 0.6667
# Epoch 53/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6389 - accuracy: 0.6759
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6412 - accuracy: 0.6944
# Epoch 55/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6270 - accuracy: 0.7037
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6316 - accuracy: 0.6852
# Epoch 57/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6256 - accuracy: 0.6759
# Epoch 58/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6406 - accuracy: 0.6667
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6426 - accuracy: 0.6481
# Epoch 60/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6358 - accuracy: 0.6481
# Epoch 61/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6499 - accuracy: 0.6389
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6469 - accuracy: 0.6389
# Epoch 63/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6482 - accuracy: 0.6389
# Epoch 64/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6467 - accuracy: 0.6389
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6465 - accuracy: 0.6389
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6462 - accuracy: 0.6389
# Epoch 67/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6461 - accuracy: 0.6389
# Epoch 68/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6456 - accuracy: 0.6389
# Epoch 69/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6454 - accuracy: 0.6389
# Epoch 70/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6457 - accuracy: 0.6389
# Epoch 71/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6439 - accuracy: 0.6389
# Epoch 72/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6490 - accuracy: 0.6389
# Epoch 73/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6509 - accuracy: 0.6389
# Epoch 74/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6509 - accuracy: 0.6389
# Epoch 75/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6461 - accuracy: 0.6389
# Epoch 76/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6445 - accuracy: 0.6389
# Epoch 77/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6444 - accuracy: 0.6389
# Epoch 78/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6439 - accuracy: 0.6389
# Epoch 79/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6449 - accuracy: 0.6481
# Epoch 80/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6430 - accuracy: 0.6481
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6426 - accuracy: 0.6481
# Epoch 82/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6436 - accuracy: 0.6481
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6428 - accuracy: 0.6574
# Epoch 84/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6417 - accuracy: 0.6574
# Epoch 85/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6407 - accuracy: 0.6574
# Epoch 86/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6407 - accuracy: 0.6574
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6416 - accuracy: 0.6574
# Epoch 88/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6400 - accuracy: 0.6574
# Epoch 89/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6408 - accuracy: 0.6574
# Epoch 90/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6398 - accuracy: 0.6574
# Epoch 91/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6400 - accuracy: 0.6574
# Epoch 92/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6400 - accuracy: 0.6574
# Epoch 93/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6396 - accuracy: 0.6574
# Epoch 94/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6390 - accuracy: 0.6574
# Epoch 95/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6393 - accuracy: 0.6574
# Epoch 96/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6388 - accuracy: 0.6574
# Epoch 97/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6392 - accuracy: 0.6574
# Epoch 98/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6386 - accuracy: 0.6574
# Epoch 99/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6385 - accuracy: 0.6574
# Epoch 100/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6391 - accuracy: 0.6574
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6380 - accuracy: 0.6574
# Epoch 102/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6391 - accuracy: 0.6574
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6396 - accuracy: 0.6574
# Epoch 104/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6380 - accuracy: 0.6574
# Epoch 105/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6377 - accuracy: 0.6574
# Epoch 106/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6379 - accuracy: 0.6574
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.6574
# Epoch 108/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6393 - accuracy: 0.6574
# Epoch 109/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6382 - accuracy: 0.6574
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6377 - accuracy: 0.6574
# Epoch 111/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6374 - accuracy: 0.6574
# Epoch 112/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6372 - accuracy: 0.6574
# Epoch 113/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6371 - accuracy: 0.6574
# Epoch 114/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6369 - accuracy: 0.6574
# Epoch 115/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6371 - accuracy: 0.6574
# Epoch 116/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6367 - accuracy: 0.6574
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.6574
# Epoch 118/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6368 - accuracy: 0.6574
# Epoch 119/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6361 - accuracy: 0.6574
# Epoch 120/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.6574
# Epoch 121/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6361 - accuracy: 0.6574
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6574
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6364 - accuracy: 0.6574
# Epoch 124/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6360 - accuracy: 0.6574
# Epoch 125/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6381 - accuracy: 0.6574
# Epoch 126/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6574
# Epoch 127/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6351 - accuracy: 0.6574
# Epoch 128/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6349 - accuracy: 0.6574
# Epoch 129/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6360 - accuracy: 0.6574
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6574
# Epoch 131/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6359 - accuracy: 0.6574
# Epoch 132/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6345 - accuracy: 0.6574
# Epoch 133/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6373 - accuracy: 0.6574
# Epoch 134/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6369 - accuracy: 0.6574
# Epoch 135/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6350 - accuracy: 0.6574
# Epoch 136/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6340 - accuracy: 0.6667
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6389 - accuracy: 0.6667
# Epoch 138/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6391 - accuracy: 0.6667
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6377 - accuracy: 0.6667
# Epoch 140/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6352 - accuracy: 0.6574
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6574
# Epoch 142/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6347 - accuracy: 0.6574
# Epoch 143/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6361 - accuracy: 0.6574
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6353 - accuracy: 0.6667
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6340 - accuracy: 0.6667
# Epoch 146/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6336 - accuracy: 0.6574
# Epoch 147/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6356 - accuracy: 0.6574
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6358 - accuracy: 0.6574
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6340 - accuracy: 0.6574
# Epoch 150/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6333 - accuracy: 0.6667
# Epoch 151/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6354 - accuracy: 0.6667
# Epoch 152/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6375 - accuracy: 0.6667
# Epoch 153/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6360 - accuracy: 0.6667
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6342 - accuracy: 0.6574
# Epoch 155/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6331 - accuracy: 0.6574
# Epoch 156/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6343 - accuracy: 0.6667
# Epoch 157/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6334 - accuracy: 0.6667
# Epoch 158/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6340 - accuracy: 0.6574
# Epoch 159/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6574
# Epoch 160/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6334 - accuracy: 0.6574
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.6574
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6339 - accuracy: 0.6574
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6335 - accuracy: 0.6574
# Epoch 164/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6323 - accuracy: 0.6667
# Epoch 165/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6332 - accuracy: 0.6667
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6333 - accuracy: 0.6667
# Epoch 167/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6334 - accuracy: 0.6667
# Epoch 168/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6319 - accuracy: 0.6667
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6320 - accuracy: 0.6574
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6338 - accuracy: 0.6574
# Epoch 171/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6574
# Epoch 172/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6318 - accuracy: 0.6574
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6330 - accuracy: 0.6667
# Epoch 174/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6303 - accuracy: 0.6574
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6527 - accuracy: 0.5000
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6565 - accuracy: 0.6574
# Epoch 177/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6389 - accuracy: 0.6574
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6360 - accuracy: 0.6574
# Epoch 179/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6393 - accuracy: 0.6574
# Epoch 180/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6375 - accuracy: 0.6574
# Epoch 181/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6348 - accuracy: 0.6574
# Epoch 182/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6359 - accuracy: 0.6574
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6358 - accuracy: 0.6574
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6353 - accuracy: 0.6574
# Epoch 185/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6345 - accuracy: 0.6574
# Epoch 186/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6344 - accuracy: 0.6574
# Epoch 187/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6374 - accuracy: 0.6574
# Epoch 188/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6390 - accuracy: 0.6574
# Epoch 189/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6364 - accuracy: 0.6574
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6574
# Epoch 191/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6350 - accuracy: 0.6574
# Epoch 192/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6345 - accuracy: 0.6574
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.6574
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6574
# Epoch 195/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6346 - accuracy: 0.6574
# Epoch 196/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6353 - accuracy: 0.6574
# Epoch 197/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6353 - accuracy: 0.6574
# Epoch 198/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6338 - accuracy: 0.6574
# Epoch 199/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6344 - accuracy: 0.6574
# Epoch 200/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6339 - accuracy: 0.6574
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8160 - accuracy: 0.3333
# [0.8159597516059875, 0.3333333432674408]

# %%
y_predicted = model.predict(X_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test, y_predicted_labels))
print(classification_report(y_test,y_predicted_labels))
print("Accurecy: ",accuracy_score(y_test, y_predicted_labels))
# Out:
# [[19  0]
#  [38  0]]
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50        19
#            1       0.00      0.00      0.00        38
#
#     accuracy                           0.33        57
#    macro avg       0.17      0.50      0.25        57
# weighted avg       0.11      0.33      0.17        57
#
# Accurecy:  0.3333333333333333
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# #Result

# %%
models=[]

for i in result:
  models.append(i[0])
  print(i[0],i[1]," : ",result[i])
  print("---------------------------------------------------------------")
  print()
# Out:
# AdaBoostClassifier(random_state=0) 1  :  0.5789473684210527
# ---------------------------------------------------------------
#
# AdaBoostClassifier(n_estimators=8, random_state=0) 1  :  0.6842105263157895
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(random_state=0) 2  :  0.6491228070175439
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(n_estimators=69, random_state=0) 2  :  0.7017543859649122
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(max_depth=1, random_state=0) 2  :  0.7368421052631579
# ---------------------------------------------------------------
#
# GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0) 2  :  0.6666666666666666
# ---------------------------------------------------------------
#
# RandomForestClassifier(random_state=0) 3  :  0.5964912280701754
# ---------------------------------------------------------------
#
# RandomForestClassifier(n_estimators=3, random_state=0) 3  :  0.6666666666666666
# ---------------------------------------------------------------
#
# RandomForestClassifier(max_depth=2, random_state=0) 3  :  0.5964912280701754
# ---------------------------------------------------------------
#
# RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0) 3  :  0.543859649122807
# ---------------------------------------------------------------
#
# XGBClassifier() 4  :  0.6666666666666666
# ---------------------------------------------------------------
#
# XGBClassifier(max_depth=1) 4  :  0.7192982456140351
# ---------------------------------------------------------------
#
# XGBClassifier(n_estimators=34) 4  :  0.7017543859649122
# ---------------------------------------------------------------
#
# XGBClassifier(max_depth=1, n_estimators=34) 4  :  0.5789473684210527
# ---------------------------------------------------------------
#
# KNeighborsClassifier() 5  :  0.3684210526315789
# ---------------------------------------------------------------
#
# KNeighborsClassifier(n_neighbors=43) 5  :  0.49122807017543857
# ---------------------------------------------------------------
#
# GaussianNB() 6  :  0.6666666666666666
# ---------------------------------------------------------------

# %%
sorted_list=[]
sorted_list = sorted(result, key=result.get,reverse=True)

for i in sorted_list:
  print(i,"  : ",result[i])
  print("-------------------------------------------------------------------------------------------------")

print(sorted_list)


flage=[]
best_models=[]
it=0

for i in sorted_list:
  if it==4:
    break

  if i[1] not in flage:
    best_models.append((i[0],i[2]))
    flage.append(i[1])
    it+=1
# Out:
# (GradientBoostingClassifier(max_depth=1, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7368421052631579
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(max_depth=1), 4, 'xgboost')   :  0.7192982456140351
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(n_estimators=69, random_state=0), 2, 'GradientBoostingClassifier')   :  0.7017543859649122
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(n_estimators=34), 4, 'xgboost')   :  0.7017543859649122
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(n_estimators=8, random_state=0), 1, 'AdaBoostClassifier')   :  0.6842105263157895
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0), 2, 'GradientBoostingClassifier')   :  0.6666666666666666
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(n_estimators=3, random_state=0), 3, 'RandomForestClassifier')   :  0.6666666666666666
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(), 4, 'xgboost')   :  0.6666666666666666
# -------------------------------------------------------------------------------------------------
# (GaussianNB(), 6, 'GaussianNB')   :  0.6666666666666666
# -------------------------------------------------------------------------------------------------
# (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier')   :  0.6491228070175439
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier')   :  0.5964912280701754
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=2, random_state=0), 3, 'RandomForestClassifier')   :  0.5964912280701754
# -------------------------------------------------------------------------------------------------
# (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier')   :  0.5789473684210527
# -------------------------------------------------------------------------------------------------
# (XGBClassifier(max_depth=1, n_estimators=34), 4, 'xgboost')   :  0.5789473684210527
# -------------------------------------------------------------------------------------------------
# (RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0), 3, 'RandomForestClassifier')   :  0.543859649122807
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(n_neighbors=43), 5, 'KNeighborsClassifier')   :  0.49122807017543857
# -------------------------------------------------------------------------------------------------
# (KNeighborsClassifier(), 5, 'KNeighborsClassifier')   :  0.3684210526315789
# -------------------------------------------------------------------------------------------------
# [(GradientBoostingClassifier(max_depth=1, random_state=0), 2, 'GradientBoostingClassifier'), (XGBClassifier(max_depth=1), 4, 'xgboost'), (GradientBoostingClassifier(n_estimators=69, random_state=0), 2, 'GradientBoostingClassifier'), (XGBClassifier(n_estimators=34), 4, 'xgboost'), (AdaBoostClassifier(n_estimators=8, random_state=0), 1, 'AdaBoostClassifier'), (GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(n_estimators=3, random_state=0), 3, 'RandomForestClassifier'), (XGBClassifier(), 4, 'xgboost'), (GaussianNB(), 6, 'GaussianNB'), (GradientBoostingClassifier(random_state=0), 2, 'GradientBoostingClassifier'), (RandomForestClassifier(random_state=0), 3, 'RandomForestClassifier'), (RandomForestClassifier(max_depth=2, random_state=0), 3, 'RandomForestClassifier'), (AdaBoostClassifier(random_state=0), 1, 'AdaBoostClassifier'), (XGBClassifier(max_depth=1, n_estimators=34), 4, 'xgboost'), (RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0), 3, 'RandomForestClassifier'), (KNeighborsClassifier(n_neighbors=43), 5, 'KNeighborsClassifier'), (KNeighborsClassifier(), 5, 'KNeighborsClassifier')]

# %%
print("best_models:")
for i in best_models:
  print(i)
# Out:
# best_models:
# (GradientBoostingClassifier(max_depth=1, random_state=0), 'GradientBoostingClassifier')
# (XGBClassifier(max_depth=1), 'xgboost')
# (AdaBoostClassifier(n_estimators=8, random_state=0), 'AdaBoostClassifier')
# (RandomForestClassifier(n_estimators=3, random_state=0), 'RandomForestClassifier')

# %%
len(best_models)
# Out:
# 4

# %% [markdown]
# #Testing Accuracy For Best 4 Models

# %%
for i in best_models:
  print("--------------------------------------------------")
  print(i[0])
  y_pred=i[0].predict(X_train)
  print(confusion_matrix(y_train, y_pred))
  print(classification_report(y_train,y_pred))
  print("Accurecy: ",accuracy_score(y_train, y_pred))
# Out:
# --------------------------------------------------
# GradientBoostingClassifier(max_depth=1, random_state=0)
# [[64  3]
#  [ 6 35]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        67
#            1       0.92      0.85      0.89        41
#
#     accuracy                           0.92       108
#    macro avg       0.92      0.90      0.91       108
# weighted avg       0.92      0.92      0.92       108
#
# Accurecy:  0.9166666666666666
# --------------------------------------------------
# XGBClassifier(max_depth=1)
# [[63  4]
#  [ 7 34]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        67
#            1       0.89      0.83      0.86        41
#
#     accuracy                           0.90       108
#    macro avg       0.90      0.88      0.89       108
# weighted avg       0.90      0.90      0.90       108
#
# Accurecy:  0.8981481481481481
# --------------------------------------------------
# AdaBoostClassifier(n_estimators=8, random_state=0)
# [[60  7]
#  [ 3 38]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        67
#            1       0.84      0.93      0.88        41
#
#     accuracy                           0.91       108
#    macro avg       0.90      0.91      0.90       108
# weighted avg       0.91      0.91      0.91       108
#
# Accurecy:  0.9074074074074074
# --------------------------------------------------
# RandomForestClassifier(n_estimators=3, random_state=0)
# [[64  3]
#  [ 2 39]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        67
#            1       0.93      0.95      0.94        41
#
#     accuracy                           0.95       108
#    macro avg       0.95      0.95      0.95       108
# weighted avg       0.95      0.95      0.95       108
#
# Accurecy:  0.9537037037037037

# %% [markdown]
# #Model Check Box

# %%
def models_check_box(models):
  import ipywidgets as widgets
  from IPython.display import display
  new_keys=[]
  for i in models:
    i=widgets.Checkbox(
      value=False,
      description=str(i),
      disabled=False,
      indent=False
      )
    display(i)
    new_keys.append(i)
  return new_keys

# %% [markdown]
# #SHAP

# %%
# !pip install shap
import shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.41.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.21.6)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.64.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.7.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.5.0)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.56.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.39.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->shap) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->shap) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.1.0)

# %%
def SHAP_EXP(model,graph_feat):
  print("Models: ",model)

  explainer = shap.Explainer(model.predict, X_test)

  shap_values1 = explainer(X_test)
  features_names=list_of_feat

  if 'Subjects' in features_names:
    features_names.pop(0)


  shap.plots.bar(shap_values1,max_display=graph_feat["max_display"])

  print("---------------------")

  shap.summary_plot(shap_values1,max_display=graph_feat["max_display"],feature_names=features_names)

  print("---------------------")

  print("Local Explaination")
  shap.plots.waterfall(shap_values1[graph_feat["shap_values Index"]],max_display=graph_feat["max_display"])


  print("---------------------")

  shap.plots.bar(shap_values1[graph_feat["shap_values Index"]],max_display=graph_feat["max_display"])

# %%
new_keys_7=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
graph_feat={
    "max_display":20,
    "shap_values Index":2
}

for i in range(len(new_keys_7)):
  if new_keys_7[i].value ==True:
    SHAP_EXP(models[i],graph_feat)
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")
    print("---------------------------------------------------------")

# %% [markdown]
# #Confusion Matrix For Training

# %%
new_keys_5=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
for i in range(len(new_keys_5)):
  if new_keys_5[i].value ==True:
    cm = ConfusionMatrix(models[i], classes=classes)

    cm.fit(X_train, y_train)
    cm.score(X_train, y_train)
    cm.show()
    print("-------------------------------")
    print("-------------------------------")

# %% [markdown]
# #Confusion Matrix For Testing

# %%
new_keys_6=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
from yellowbrick.classifier import ConfusionMatrix


for i in range(len(new_keys_6)):
  if new_keys_6[i].value ==True:
    cm = ConfusionMatrix(models[i], classes=classes)

    cm.fit(X_train, y_train)
    cm.score(X_test, y_test)
    cm.show()

# %% [markdown]
# #ROC Comparaing Machine Learning Models

# %%
def ROC(mod,X_t,y_t,graph_feat):
  r_probs = [0 for _ in range(len(y_t))]

  model_probs = []


  for i in mod:
    model_probs.append(i.predict_proba(X_t))


  model_probs2=[]

  for i in model_probs:
    model_probs2.append(i[:,1])


  from sklearn.metrics import roc_curve, roc_auc_score

  model_auc=[]
  r_auc = roc_auc_score(y_t, r_probs)

  for i in model_probs2:
    model_auc.append(roc_auc_score(y_t,i))


  fpr_tpr=[]
  r_fpr, r_tpr, _ = roc_curve(y_t, r_probs)

  for i in model_probs2:
    fpr, tpr, _ = roc_curve(y_t, i)
    fpr_tpr.append((fpr,tpr))

  import matplotlib.pyplot as plt
  plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)

  for i in range(len(model_auc)):
    plt.plot(fpr_tpr[i][0], fpr_tpr[i][1], marker='.', label=str(mod[i])+' (AUROC = %0.3f)' % model_auc[i])

  # Title
  plt.title(graph_feat["Title"],fontsize= graph_feat["Title Size"], fontweight=graph_feat["Title Fontweight"])
  plt.xlabel('False Positive Rate',fontweight=graph_feat["X axis Label Fontweight"],fontsize=graph_feat["X axis Label Font Size"])
  plt.ylabel('True Positive Rate',fontweight=graph_feat["Y axis Label Fontweight"],fontsize=graph_feat["Y axis Label Font Size"])
  
  plt.legend( 
           prop = {'size' : graph_feat["legend Font Size"]}, 
           loc = graph_feat["legend Position"])
  
  fig = plt.gcf()
  fig.set_size_inches(graph_feat["Fig Width (inches)"], graph_feat["Fig Height (inches)"])
  fig.savefig(graph_feat["Fig Saving Name"], dpi=graph_feat["dpi"])
  plt.show()

# %% [markdown]
# ***Training ROC***<br>
# Chosse the Models

# %%
new_keys_2=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %% [markdown]
# Change  the given dictionary of graph feature for desire graph.

# %%
graph_feat={
    "Title" : "ROC Plot Training",
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_training.png",
    "dpi":100
    

}

mod=[]
for i in range(len(new_keys_2)):
  if new_keys_2[i].value ==True:
    mod.append(models[i])

ROC(mod,X_train,y_train,graph_feat)

# %% [markdown]
# ---

# %% [markdown]
# ***Testing ROC***<br>
# Chosse the Models

# %%
new_keys_3=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %% [markdown]
# Change  the given dictionary of graph feature for desire graph.

# %%
graph_feat={
    "Title" : "ROC Plot Testing",
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}

mod=[]
for i in range(len(new_keys_3)):
  if new_keys_3[i].value ==True:
    mod.append(models[i])

ROC(mod,X_test,y_test,graph_feat)

# %% [markdown]
# #Cross_val_score

# %%
from sklearn.model_selection import cross_val_score

k=5
for i in result:
  print(i[0]," -> Accuracy: ",result[i])
  l=list(cross_val_score(i[0],X_new.iloc[:,1:], y_new,cv=k))
  avg=sum(l)/k
  print(i[0]," -> AVG Accurecy After CV: "+str(avg)+ " (For "+str(k)+" Fold)")
  print("--------------------------------------------------------------------------")
# Out:
# AdaBoostClassifier(random_state=0)  -> Accuracy:  0.5789473684210527
# AdaBoostClassifier(random_state=0)  -> AVG Accurecy After CV: 0.6848484848484848 (For 5 Fold)
# --------------------------------------------------------------------------
# AdaBoostClassifier(n_estimators=8, random_state=0)  -> Accuracy:  0.6842105263157895
# AdaBoostClassifier(n_estimators=8, random_state=0)  -> AVG Accurecy After CV: 0.6666666666666667 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(random_state=0)  -> Accuracy:  0.6491228070175439
# GradientBoostingClassifier(random_state=0)  -> AVG Accurecy After CV: 0.703030303030303 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(n_estimators=69, random_state=0)  -> Accuracy:  0.7017543859649122
# GradientBoostingClassifier(n_estimators=69, random_state=0)  -> AVG Accurecy After CV: 0.696969696969697 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(max_depth=1, random_state=0)  -> Accuracy:  0.7368421052631579
# GradientBoostingClassifier(max_depth=1, random_state=0)  -> AVG Accurecy After CV: 0.7090909090909091 (For 5 Fold)
# --------------------------------------------------------------------------
# GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)  -> Accuracy:  0.6666666666666666
# GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)  -> AVG Accurecy After CV: 0.7151515151515151 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(random_state=0)  -> Accuracy:  0.5964912280701754
# RandomForestClassifier(random_state=0)  -> AVG Accurecy After CV: 0.7333333333333334 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(n_estimators=3, random_state=0)  -> Accuracy:  0.6666666666666666
# RandomForestClassifier(n_estimators=3, random_state=0)  -> AVG Accurecy After CV: 0.6363636363636364 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(max_depth=2, random_state=0)  -> Accuracy:  0.5964912280701754
# RandomForestClassifier(max_depth=2, random_state=0)  -> AVG Accurecy After CV: 0.7454545454545455 (For 5 Fold)
# --------------------------------------------------------------------------
# RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)  -> Accuracy:  0.543859649122807
# RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)  -> AVG Accurecy After CV: 0.6121212121212122 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier()  -> Accuracy:  0.6666666666666666
# XGBClassifier()  -> AVG Accurecy After CV: 0.7090909090909091 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier(max_depth=1)  -> Accuracy:  0.7192982456140351
# XGBClassifier(max_depth=1)  -> AVG Accurecy After CV: 0.7212121212121212 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier(n_estimators=34)  -> Accuracy:  0.7017543859649122
# XGBClassifier(n_estimators=34)  -> AVG Accurecy After CV: 0.6848484848484848 (For 5 Fold)
# --------------------------------------------------------------------------
# XGBClassifier(max_depth=1, n_estimators=34)  -> Accuracy:  0.5789473684210527
# XGBClassifier(max_depth=1, n_estimators=34)  -> AVG Accurecy After CV: 0.696969696969697 (For 5 Fold)
# --------------------------------------------------------------------------
# KNeighborsClassifier()  -> Accuracy:  0.3684210526315789
# KNeighborsClassifier()  -> AVG Accurecy After CV: 0.5212121212121212 (For 5 Fold)
# --------------------------------------------------------------------------
# KNeighborsClassifier(n_neighbors=43)  -> Accuracy:  0.49122807017543857
# KNeighborsClassifier(n_neighbors=43)  -> AVG Accurecy After CV: 0.6424242424242425 (For 5 Fold)
# --------------------------------------------------------------------------
# GaussianNB()  -> Accuracy:  0.6666666666666666
# GaussianNB()  -> AVG Accurecy After CV: 0.703030303030303 (For 5 Fold)
# --------------------------------------------------------------------------

# %% [markdown]
# #CV ROC

# %%
def CV_ROC(model,folds,graph_feat):
  import matplotlib.pyplot as plt

  from sklearn import svm
  from sklearn.metrics import auc,roc_curve
  from sklearn.metrics import RocCurveDisplay
  from sklearn.model_selection import StratifiedKFold


  cv = StratifiedKFold(n_splits=folds)



  tprs = []
  aucs = []
  mean_fpr = np.linspace(0,1,100)
  i = 1
  for train,test in cv.split(X_new.iloc[:,1:], y_new.values):
      prediction = model.fit(X_new.iloc[:,1:].values[train], y_new.values[train]).predict_proba(X_new.iloc[:,1:].values[test])
      fpr, tpr, t = roc_curve(y_new.values[test], prediction[:, 1])
      tprs.append(np.interp(mean_fpr, fpr, tpr))
      roc_auc = auc(fpr, tpr)
      aucs.append(roc_auc)
      plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
      i= i+1

  plt.plot([0,1],[0,1],linestyle = '--',lw = 2,color = 'black')
  mean_tpr = np.mean(tprs, axis=0)
  mean_auc = auc(mean_fpr, mean_tpr)
  plt.plot(mean_fpr, mean_tpr, color='blue',
          label=r'Mean ROC (AUC = %0.2f )' % (mean_auc),lw=2, alpha=1)

  plt.title('CV-ROC-> '+str(model),fontsize= graph_feat["Title Size"], fontweight=graph_feat["Title Fontweight"])
  plt.xlabel('False Positive Rate',fontweight=graph_feat["X axis Label Fontweight"],fontsize=graph_feat["X axis Label Font Size"])
  plt.ylabel('True Positive Rate',fontweight=graph_feat["Y axis Label Fontweight"],fontsize=graph_feat["Y axis Label Font Size"])
  plt.legend( 
           prop = {'size' : graph_feat["legend Font Size"]}, 
           loc = graph_feat["legend Position"])
  
  fig = plt.gcf()
  fig.set_size_inches(graph_feat["Fig Width (inches)"], graph_feat["Fig Height (inches)"])
  fig.savefig(graph_feat["Fig Saving Name"], dpi=graph_feat["dpi"])
  plt.show()

# %%
new_keys=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
# run this cell after selecting

graph_feat={
    "Title Size":18,
    "Title Fontweight":'bold',

    "legend Font Size": 14,
    "legend Position": "lower right",

    "X axis Label Font Size":16,
    "X axis Label Fontweight":'bold',

    "Y axis Label Font Size":16,
    "Y axis Label Fontweight":'bold',

    "Fig Height (inches)":10.8,
    "Fig Width (inches)":18.8,

    "Fig Saving Name": "ROC_testing.png",
    "dpi":100

}





k_fold=5

for i in range(len(new_keys)):
  if new_keys[i].value ==True:
    CV_ROC(models[i],5,graph_feat)
    print("-----------------------------------------------------------------")
    print("-----------------------------------------------------------------")

# %% [markdown]
# #Result CSV<br>
# Predicted and Actual Row will be added at the end index

# %%
def reverse_transfrom(my_list):
  for i in range(len(my_list)):
    if my_list[i] == 0:
      my_list[i] = 'Control'
    else:
      my_list[i] = 'Patient'
  return my_list

# %%
new_keys_4=models_check_box(models)
# Out:
# Checkbox(value=False, description='AdaBoostClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='AdaBoostClassifier(n_estimators=8, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(n_estimators=69, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, random_state=0)', indent=False)
# Checkbox(value=False, description='GradientBoostingClassifier(max_depth=1, n_estimators=69, random_state=0)', …
# Checkbox(value=False, description='RandomForestClassifier(random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(n_estimators=3, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, random_state=0)', indent=False)
# Checkbox(value=False, description='RandomForestClassifier(max_depth=2, n_estimators=3, random_state=0)', inden…
# Checkbox(value=False, description='XGBClassifier()', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1)', indent=False)
# Checkbox(value=False, description='XGBClassifier(n_estimators=34)', indent=False)
# Checkbox(value=False, description='XGBClassifier(max_depth=1, n_estimators=34)', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier()', indent=False)
# Checkbox(value=False, description='KNeighborsClassifier(n_neighbors=43)', indent=False)
# Checkbox(value=False, description='GaussianNB()', indent=False)

# %%
for i in range(len(new_keys_4)):
  if new_keys_4[i].value ==True:
    temp=X_test_with_subject

    prediction_cls = reverse_transfrom(list(models[i].predict(X_test[0:])))
    actual_cls = reverse_transfrom(list(y_test[0:]))

    temp["Actual"] = actual_cls
    temp["Predicted"] = prediction_cls

    temp.to_csv(str(models[i])+".csv")
