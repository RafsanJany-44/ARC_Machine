# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC_Machine/blob/main/Tinnitus_PreTraining_Tunning_Hybride.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Function

# %%
# !pip install imbalanced-learn
# !pip install ipywidgets

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
import ipywidgets as widgets
from joblib import Parallel, delayed
from google.colab import files
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


def dataset_balance(X_temp, y_temp):
  smote = SMOTE()
  X_temp, y_temp= smote.fit_resample(X_temp, y_temp)
  return pd.concat([pd.DataFrame(X_temp), pd.DataFrame(y_temp)], axis=1)


def Xy_balance(X_temp, y_temp):
  smote = SMOTE()
  return smote.fit_resample(X_temp, y_temp)


def save_model(model,model_name):
 joblib.dump(model, model_name)
  

def load_model(model_name):
  return joblib.load(model_name)


def Search_Null(dataset):
  dic={}
  for col in list(dataset.columns):
    rows = []
    flage = 0
    for row in range(dataset.shape[0]):
      if str(dataset[col][row]) == "nan":
        rows.append(row)
        flage = 1
    if flage ==1:
      dic[col] = rows
  return dic



def divide_dataset(dataset,percentage,random_state = 0):
  rows,cols = dataset.shape
  if random_state == 0:
    return dataset.iloc[:int(rows*(percentage)),:]
  else:
    import random
    l_r = random.sample(range(0, rows), int(rows*(percentage)))
    return dataset.iloc[l_r,:]



def StandardScaleData(data):
  scaler = StandardScaler()
  scaler.fit(data)
  return  scaler.transform(data)



def MinMaxScaleData(data):
  scaler = MinMaxScaler()
  scaler.fit(data)
  return scaler.transform(data)


def tune_report_csv(model,dic,feat_selection_method,number_of_feat):

  tunning_type = []
  accuracy = []
  scaled_accuracy = []
  model_name = []
  feature_selection_method = []
  number_of_features = []

  li = ["Smote : NO    ; Scaling : Train(Standard)",
      "Smote : NO    ; Scaling : Train(MinMax)",
      "Smote : Train ; Scaling : Train(Standard)",
      "Smote : Train ; Scaling : Train(MinMax)",
      "Smote : All   ; Scaling : Train(Standard)",
      "Smote : All   ; Scaling : Train(MinMax)"]

  for i in list(dic.keys()):
    X_train, X_test, y_train, y_test = dic[i]
    
    if i in li and str(model[:3]) == "xgb":
      model.fit(X_train,y_train.values)
      y_pred = model.predict(X_test.values)
    else:
      model.fit(X_train,y_train)
      y_pred = model.predict(X_test)

    accu =accuracy_score(y_test, y_pred)
    scaled_accu =  float("{:.2f}".format(accu))
    print(i)
    print("Accurecy: ",scaled_accu)
    tunning_type.append(i)
    accuracy.append(accu)
    scaled_accuracy.append(scaled_accu)
    model_name.append(model)
    feature_selection_method.append(feat_selection_method)
    number_of_features.append(number_of_feat)
    
    print("------------------------------------------------------------------------------")
    print("------------------------------------------------------------------------------")

  csv_dic={
      "model_name"  : model_name,
      "tunning_type" : tunning_type,
      "accurecy"    : accuracy, 
      "scaled_accuracy" :scaled_accuracy,
      "feature_selection_method" : feature_selection_method,
      "number_of_features" : number_of_features
  }


  df = pd.DataFrame.from_dict(csv_dic)
  df.to_csv("/content/drive/MyDrive/Iqram Sir/Tinnitus/Features_CSV/"+feat_selection_method+"_"+str(number_of_feat)+"_"+str(model)+".csv",index = False)
  return "Tunning Data Report is Secured for this phase!!!"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (7.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (5.7.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.16.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.3)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.12.1)

# %% [markdown]
# #Starting

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Iqram Sir/Tinnitus/Tinnitus_106 feature_ALR_EEG_2023.02.08_OnlyGap_No_n0p1p3.csv")
print(dataset.shape)
target = "Class"

#Encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dataset[target]=encoder.fit_transform(dataset[target])

#dataset = divide_dataset(dataset,0.04611,1)
#print(dataset.shape)
# Out:
# (165, 77)

# %% [markdown]
# ###Spliting into X and y

# %%
X = dataset.iloc[:,3:]
y = dataset[target]
col=list(dataset.iloc[0:0,3:])
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 74 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   n1_gap_peak_ms_20ms           165 non-null    int64
#  1   p2_gap_peak_ms_20ms           165 non-null    int64
#  2   n2_gap_peak_ms_20ms           165 non-null    int64
#  3   n1p2_interval_gap_20ms        165 non-null    int64
#  4   n1n2_interval_gap_20ms        165 non-null    int64
#  5   p2n2_interval_gap_20ms        165 non-null    int64
#  6   n1_gap_peak_amp_20ms          165 non-null    float64
#  7   p2_gap_peak_amp_20ms          165 non-null    float64
#  8   n2_gap_peak_amp_20ms          165 non-null    float64
#  9   n1p2_gap_diff_20ms            165 non-null    float64
#  10  p2n2_gap_diff_20ms            165 non-null    float64
#  11  n1p2_gap_nogap_diff_20ms      165 non-null    float64
#  12  p2n2_gap_nogap_diff_20ms      165 non-null    float64
#  13  n1p2_gap_no_gap_ratio_20ms    165 non-null    float64
#  14  p2n2_gap_no_gap_ratio_20ms    165 non-null    float64
#  15  gap_auc_n1p2_LO_20ms          165 non-null    float64
#  16  gap_auc_n1p2_UP_20ms          165 non-null    float64
#  17  gap_auc_p2n2_UP_20ms          165 non-null    float64
#  18  gap_auc_n1p2n2_20ms           165 non-null    float64
#  19  gap_auc_total_20ms            165 non-null    float64
#  20  gap_auc_total_abs_20ms        165 non-null    float64
#  21  gap_auc_n1p2n2_by_total_20ms  165 non-null    float64
#  22  alpha_peak_amp_20ms           165 non-null    float64
#  23  alpha_peak_freq_20ms          165 non-null    float64
#  24  beta_peak_amp_20ms            165 non-null    float64
#  25  beta_peak_freq_20ms           165 non-null    float64
#  26  gamma_peak_amp_20ms           165 non-null    float64
#  27  gamma_peak_freq_20ms          165 non-null    float64
#  28  alpha_auc_20ms                165 non-null    float64
#  29  beta_auc_20ms                 165 non-null    float64
#  30  gamma_auc_20ms                165 non-null    float64
#  31  total_auc_20ms                165 non-null    float64
#  32  alpha_peak_auc_20ms           165 non-null    float64
#  33  beta_peak_auc_20ms            165 non-null    float64
#  34  gamma_peak_auc_20ms           165 non-null    float64
#  35  ABR_peak_auc_20ms             165 non-null    float64
#  36  ABR_auc_20ms                  165 non-null    float64
#  37  n1_gap_peak_ms_50ms           165 non-null    int64
#  38  p2_gap_peak_ms_50ms           165 non-null    int64
#  39  n2_gap_peak_ms_50ms           165 non-null    int64
#  40  n1p2_interval_gap_50ms        165 non-null    int64
#  41  n1n2_interval_gap_50ms        165 non-null    int64
#  42  p2n2_interval_gap_50ms        165 non-null    int64
#  43  n1_gap_peak_amp_50ms          165 non-null    float64
#  44  p2_gap_peak_amp_50ms          165 non-null    float64
#  45  n2_gap_peak_amp_50ms          165 non-null    float64
#  46  n1p2_gap_diff_50ms            165 non-null    float64
#  47  p2n2_gap_diff_50ms            165 non-null    float64
#  48  n1p2_gap_nogap_diff_50ms      165 non-null    float64
#  49  p2n2_gap_nogap_diff_50ms      165 non-null    float64
#  50  n1p2_gap_no_gap_ratio_50ms    165 non-null    float64
#  51  p2n2_gap_no_gap_ratio_50ms    165 non-null    float64
#  52  gap_auc_n1p2_LO_50ms          165 non-null    float64
#  53  gap_auc_n1p2_UP_50ms          165 non-null    float64
#  54  gap_auc_p2n2_UP_50ms          165 non-null    float64
#  55  gap_auc_n1p2n2_50ms           165 non-null    float64
#  56  gap_auc_total_50ms            165 non-null    float64
#  57  gap_auc_total_abs_50ms        165 non-null    float64
#  58  gap_auc_n1p2n2_by_total_50ms  165 non-null    float64
#  59  alpha_peak_amp_50ms           165 non-null    float64
#  60  alpha_peak_freq_50ms          165 non-null    float64
#  61  beta_peak_amp_50ms            165 non-null    float64
#  62  beta_peak_freq_50ms           165 non-null    float64
#  63  gamma_peak_amp_50ms           165 non-null    float64
#  64  gamma_peak_freq_50ms          165 non-null    float64
#  65  alpha_auc_50ms                165 non-null    float64
#  66  beta_auc_50ms                 165 non-null    float64
#  67  gamma_auc_50ms                165 non-null    float64
#  68  total_auc_50ms                165 non-null    float64
#  69  alpha_peak_auc_50ms           165 non-null    float64
#  70  beta_peak_auc_50ms            165 non-null    float64
#  71  gamma_peak_auc_50ms           165 non-null    float64
#  72  ABR_peak_auc_50ms             165 non-null    float64
#  73  ABR_auc_50ms                  165 non-null    float64
# dtypes: float64(62), int64(12)
# memory usage: 95.5 KB

# %% [markdown]
# #Feature Selection

# %%
X = dataset.iloc[:,3:]
y = dataset[target]
col=list(dataset.iloc[0:0,3:])
number_of_feat = 20

# %% [markdown]
# ###ANOVA with f classifciation

# %%
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import pandas as pd



fs = SelectKBest(score_func=f_classif, k=5)
fit = fs.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_ANOVA'] 

lyst = featureScores.nlargest(number_of_feat,'Score_ANOVA')

#lyst.to_csv('Filter_Method_ANOVA_with_f_classif.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "ANOVA"

# %% [markdown]
# ###Embedded Method

# %%
from sklearn.linear_model import LassoCV
reg = LassoCV()
reg.fit(X, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,y))
coef = pd.Series(reg.coef_, index = X.columns)

print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")

imp_coef = coef.sort_values()

list_of_feat=[]


for i in range(coef.shape[0]):
  if coef[i]!=0:
    list_of_feat.append(dataset.iloc[:0,i+3].name)
    
df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Embedded_Method.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]
selection_method = "Embedded"
# Out:
# Best alpha using built-in LassoCV: 1664496.378245
# Best score using built-in LassoCV: 0.000418
# Lasso picked 4 variables and eliminated the other 45 variables

# %% [markdown]
# ###Pearson's with f regression

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
import pandas as pd


fs = SelectKBest(score_func=f_regression, k=5)
fit = fs.fit(X,y)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)

featureScores.columns = ['Best_columns','Score_pearsons'] 


lyst = featureScores.nlargest(number_of_feat,'Score_pearsons')

#lyst.to_csv('Filter_Method_Pearson’s_with_f_regression.csv')

list_of_feat = list(lyst["Best_columns"])
selection_method = "Pearson"

# %% [markdown]
# ###Sequential Feature Selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
sfs = SequentialFeatureSelector(knn, n_features_to_select=number_of_feat)
sfs.fit(X, y)
list_of_feat=[]
list_of_feat=list(sfs.get_feature_names_out(X.columns))

df = pd.DataFrame(list_of_feat, columns=['Best_Features'])

#df.to_csv("Filter_Method_Sequential_feat_Selection_KNN.csv")

list_of_feat = list(df["Best_Features"])
if number_of_feat < len(list_of_feat):
  list_of_feat = list_of_feat[:number_of_feat]

selection_method = "Sequential"

# %% [markdown]
# #Feature list

# %%
X=dataset[list_of_feat]
y=dataset[target]
print(X.shape)
# Out:
# (165, 20)

# %%
"""list_of_feat2=[   
'p2_gap_peak_amp_50ms',
'p2n2_gap_diff_20ms',
'p2n2_gap_diff_50ms',
'p2n2_interval_gap_50ms',
'n2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_by_total_20ms',
'n1_gap_peak_ms_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'n1p2_gap_no_gap_ratio_50ms',
'gap_auc_p2n2_UP_20ms',
'gap_auc_p2n2_UP_50ms',
'n2_gap_peak_ms_50ms',
'gap_auc_n1p2n2_20ms',
'n1p2_gap_diff_50ms',
'gap_auc_total_abs_20ms',
'n1_gap_peak_ms_50ms',
'n1p2_gap_no_gap_ratio_20ms',
'alpha_peak_auc_50ms',
'gamma_peak_freq_50ms',
'ABR_peak_auc_50ms'
    ]


list_of_feat3=[  
'p2n2_gap_diff_50ms',
'p2_gap_peak_amp_50ms',
'gap_auc_n1p2n2_by_total_20ms',
'gap_auc_n1p2n2_by_total_50ms',
'p2n2_gap_diff_20ms',
'n1_gap_peak_ms_20ms',
'n2_gap_peak_amp_20ms',
'gap_auc_n1p2n2_50ms',
'gap_auc_n1p2_UP_50ms',
'gap_auc_n1p2_LO_50ms',
'gap_auc_n1p2n2_20ms',
'n1_gap_peak_ms_50ms',
'gap_auc_p2n2_UP_50ms',
'n1p2_gap_no_gap_ratio_20ms',
'p2_gap_peak_amp_20ms',
'alpha_peak_auc_50ms',
'gamma_peak_freq_20ms'
    ]

selection_method="list_of_feat3"

number_of_feat = len(list_of_feat3)


X=dataset[list_of_feat3]
y=dataset[target]"""
# Out:
# 'list_of_feat2=[   \n\'p2_gap_peak_amp_50ms\',\n\'p2n2_gap_diff_20ms\',\n\'p2n2_gap_diff_50ms\',\n\'p2n2_interval_gap_50ms\',\n\'n2_gap_peak_amp_20ms\',\n\'gap_auc_n1p2n2_by_total_20ms\',\n\'n1_gap_peak_ms_20ms\',\n\'gap_auc_n1p2n2_by_total_50ms\',\n\'n1p2_gap_no_gap_ratio_50ms\',\n\'gap_auc_p2n2_UP_20ms\',\n\'gap_auc_p2n2_UP_50ms\',\n\'n2_gap_peak_ms_50ms\',\n\'gap_auc_n1p2n2_20ms\',\n\'n1p2_gap_diff_50ms\',\n\'gap_auc_total_abs_20ms\',\n\'n1_gap_peak_ms_50ms\',\n\'n1p2_gap_no_gap_ratio_20ms\',\n\'alpha_peak_auc_50ms\',\n\'gamma_peak_freq_50ms\',\n\'ABR_peak_auc_50ms\'\n    ]\n\n\nlist_of_feat3=[  \n\'p2n2_gap_diff_50ms\',\n\'p2_gap_peak_amp_50ms\',\n\'gap_auc_n1p2n2_by_total_20ms\',\n\'gap_auc_n1p2n2_by_total_50ms\',\n\'p2n2_gap_diff_20ms\',\n\'n1_gap_peak_ms_20ms\',\n\'n2_gap_peak_amp_20ms\',\n\'gap_auc_n1p2n2_50ms\',\n\'gap_auc_n1p2_UP_50ms\',\n\'gap_auc_n1p2_LO_50ms\',\n\'gap_auc_n1p2n2_20ms\',\n\'n1_gap_peak_ms_50ms\',\n\'gap_auc_p2n2_UP_50ms\',\n\'n1p2_gap_no_gap_ratio_20ms\',\n\'p2_gap_peak_amp_20ms\',\n\'alpha_peak_auc_50ms\',\n\'gamma_peak_freq_20ms\'\n    ]\n\nselection_method="list_of_feat3"\n\nnumber_of_feat = len(list_of_feat3)\n\n\nX=dataset[list_of_feat3]\ny=dataset[target]'

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   p2n2_gap_diff_50ms            165 non-null    float64
#  1   p2_gap_peak_amp_50ms          165 non-null    float64
#  2   gap_auc_n1p2n2_by_total_20ms  165 non-null    float64
#  3   gap_auc_n1p2n2_by_total_50ms  165 non-null    float64
#  4   p2n2_gap_diff_20ms            165 non-null    float64
#  5   n1_gap_peak_ms_20ms           165 non-null    int64
#  6   n2_gap_peak_amp_20ms          165 non-null    float64
#  7   n1p2_gap_diff_50ms            165 non-null    float64
#  8   gap_auc_n1p2n2_50ms           165 non-null    float64
#  9   gap_auc_p2n2_UP_20ms          165 non-null    float64
#  10  gap_auc_n1p2_UP_50ms          165 non-null    float64
#  11  gap_auc_n1p2_LO_50ms          165 non-null    float64
#  12  gap_auc_n1p2n2_20ms           165 non-null    float64
#  13  n1p2_gap_diff_20ms            165 non-null    float64
#  14  n1_gap_peak_ms_50ms           165 non-null    int64
#  15  gap_auc_p2n2_UP_50ms          165 non-null    float64
#  16  n1p2_gap_no_gap_ratio_20ms    165 non-null    float64
#  17  p2_gap_peak_amp_20ms          165 non-null    float64
#  18  gap_auc_n1p2_LO_20ms          165 non-null    float64
#  19  ABR_peak_auc_50ms             165 non-null    float64
# dtypes: float64(18), int64(2)
# memory usage: 25.9 KB

# %% [markdown]
# #Tunning for Scalling and Data Balancing

# %% [markdown]
# ##Smote : NO
# ##Scaling : NO

# %%
def tune_1():
  X_new = X
  y_new = y
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  return X_train,X_test,y_train,y_test
  #return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : All Data (Standard)

# %%
def tune_2():
  X_new = X
  y_new = y
  X_train=StandardScaleData(X_new.iloc[:133,:])
  X_test=StandardScaleData(X_new.iloc[133:,:])
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  return X_train,X_test,y_train,y_test
  #return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : All Data (MinMax)

# %%
def tune_3():
  X_new = X
  y_new = y
  
  X_train=MinMaxScaleData(X_new.iloc[:133,:]) 
  X_test=MinMaxScaleData(X_new.iloc[133:,:])
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  return X_train,X_test,y_train,y_test
  #return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : NO
# ##Scaling : Train (Stadard)

# %%
def tune_4():
  X_new = X
  y_new = y
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : NO
# ##Scaling : Train (MinMax)

# %%
def tune_5():
  X_new = X
  y_new = y
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : ALL
# ##Scaling : NO

# %%
def tune_6():
  X_new,y_new = Xy_balance(X,y)  
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  return X_train,X_test,y_train,y_test
  #return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Smote : Train
# ##Scaling : NO

# %%
def tune_7():
  X_new = X
  y_new = y
  
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  

  X_train,y_train = Xy_balance(X_train,y_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : Train
# ##Scaling : Train (Standard)

# %%
def tune_8():
  X_new = X
  y_new = y
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  X_train,y_train = Xy_balance(X_train,y_train)
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : Train
# ##Scaling : Train (MixMax)

# %%
def tune_9():
  X_new = X
  y_new = y
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  X_train,y_train = Xy_balance(X_train,y_train)
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : Train (Standard)

# %%
def tune_10():
  X_new,y_new = Xy_balance(X,y)
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  X_train = StandardScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : Train (MixMax)

# %%
def tune_11():
  X_new,y_new = Xy_balance(X,y)
  X_train=X_new.iloc[:133,:]  
  X_test=X_new.iloc[133:,:]
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  
  X_train = MinMaxScaleData(X_train)
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : All (Standard)

# %%
def tune_12():
  X_new,y_new = Xy_balance(X,y)
  X_train=StandardScaleData(X_new.iloc[:133,:])
  X_test=StandardScaleData(X_new.iloc[133:,:])
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  return X_train, X_test, y_train, y_test

# %% [markdown]
# ##Smote : All
# ##Scaling : ALL (MinMax)

# %%
def tune_13():
  X_new,y_new = Xy_balance(X,y)
  X_train=MinMaxScaleData(X_new.iloc[:133,:])
  X_test=MinMaxScaleData(X_new.iloc[133:,:])
  y_train=y_new.iloc[:133]
  y_test=y_new.iloc[133:]
  return X_train, X_test, y_train, y_test

#  return train_test_split(X_new, y_new, test_size = 0.2, random_state = 0)

# %% [markdown]
# ##Tunn Dictionary

# %%
tune_dic={
  "Smote : NO    ; Scaling : NO"                  : tune_1(),
  "Smote : NO    ; Scaling : All Data(Standard)"  : tune_2(),
  "Smote : NO    ; Scaling : All Data(MinMax)"    : tune_3(),
  #"Smote : NO    ; Scaling : Train(Standard)"     : tune_4(),
  #"Smote : NO    ; Scaling : Train(MinMax)"       : tune_5(),
  "Smote : ALL   ; Scaling : NO"                  : tune_6(),
  "Smote : Train ; Scaling : NO"                  : tune_7(),
  #"Smote : Train ; Scaling : Train(Standard)"     : tune_8(),
  #"Smote : Train ; Scaling : Train(MinMax)"       : tune_9(),
  #"Smote : All   ; Scaling : Train(Standard)"     : tune_10(),
  #"Smote : All   ; Scaling : Train(MinMax)"       : tune_11(),
  "Smote : All   ; Scaling : All(Standard)"       : tune_12(),
  "Smote : All   ; Scaling : All(MinMax)"        : tune_13()
}

# %% [markdown]
# ---

# %% [markdown]
# # **Training**

# %% [markdown]
# ##ADABOOST

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
ada_defult = AdaBoostClassifier(random_state=0)
tune_report_csv(ada_defult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.41
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.54
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 455 ms, sys: 6.41 ms, total: 462 ms
# Wall time: 463 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##Graddient Boosting

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
gradBoost_default = GradientBoostingClassifier(random_state=0)

tune_report_csv(gradBoost_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.47
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.49
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 584 ms, sys: 10.3 ms, total: 595 ms
# Wall time: 593 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ###Histogram-Based Gradient Boosting

# %%
# %%time
from sklearn.ensemble import HistGradientBoostingClassifier

hisgradBoost_default = HistGradientBoostingClassifier(random_state=0)

tune_report_csv(hisgradBoost_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.44
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.53
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.51
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 880 ms, sys: 39.2 ms, total: 919 ms
# Wall time: 496 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##Random Forest

# %%
# %%time
RanFor={}

from sklearn.ensemble import RandomForestClassifier
rf_default = RandomForestClassifier(random_state=0,n_jobs=-1)

tune_report_csv(rf_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 1.18 s, sys: 202 ms, total: 1.38 s
# Wall time: 1.18 s
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ##XGB

# %%
# %%time
import xgboost as xgb
xgb_deafult = xgb.XGBClassifier(random_state=0,n_jobs=-1)

tune_report_csv(xgb_deafult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.53
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.62
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 319 ms, sys: 2.25 ms, total: 321 ms
# Wall time: 175 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##KNN

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
knn_default = KNeighborsClassifier(n_jobs = -1)

tune_report_csv(knn_default,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.41
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.66
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.44
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.41
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.74
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 54.2 ms, sys: 6.42 ms, total: 60.6 ms
# Wall time: 61.5 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##NB

# %%
# %%time
from sklearn.naive_bayes import GaussianNB

nb_deafult = GaussianNB()

tune_report_csv(nb_deafult,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.72
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.78
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.67
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.69
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.69
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.64
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 30.3 ms, sys: 5.26 ms, total: 35.6 ms
# Wall time: 36.7 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# ##Tree algorithms

# %% [markdown]
# ###DecisionTreeRegressor

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
tune_report_csv(dtc,tune_dic,selection_method,number_of_feat)
# Out:
# Smote : NO    ; Scaling : NO
# Accurecy:  0.53
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(Standard)
# Accurecy:  0.5
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : NO    ; Scaling : All Data(MinMax)
# Accurecy:  0.53
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : ALL   ; Scaling : NO
# Accurecy:  0.56
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : Train ; Scaling : NO
# Accurecy:  0.59
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(Standard)
# Accurecy:  0.54
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# Smote : All   ; Scaling : All(MinMax)
# Accurecy:  0.51
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# CPU times: user 34.7 ms, sys: 3.16 ms, total: 37.9 ms
# Wall time: 37.2 ms
# 'Tunning Data Report is Secured for this phase!!!'

# %%
# !pip install catboost

from catboost import CatBoostClassifier
#cat = CatBoostClassifier(task_type="GPU")
cat=CatBoostClassifier()

tune_report_csv(cat,tune_dic,selection_method,number_of_feat)
# Out:
# Streaming output truncated to the last 5000 lines.
# 24:	learn: 0.6419952	total: 51.6ms	remaining: 2.01s
# 25:	learn: 0.6400688	total: 53.5ms	remaining: 2.01s
# 26:	learn: 0.6379373	total: 55.5ms	remaining: 2s
# 27:	learn: 0.6362625	total: 57.5ms	remaining: 1.99s
# 28:	learn: 0.6343564	total: 59.5ms	remaining: 1.99s
# 29:	learn: 0.6318827	total: 61.4ms	remaining: 1.99s
# 30:	learn: 0.6304385	total: 63.6ms	remaining: 1.99s
# 31:	learn: 0.6286569	total: 65.6ms	remaining: 1.99s
# 32:	learn: 0.6270619	total: 67.6ms	remaining: 1.98s
# 33:	learn: 0.6249860	total: 69.5ms	remaining: 1.98s
# 34:	learn: 0.6231887	total: 71.5ms	remaining: 1.97s
# 35:	learn: 0.6213023	total: 73.4ms	remaining: 1.97s
# 36:	learn: 0.6190709	total: 75.4ms	remaining: 1.96s
# 37:	learn: 0.6173041	total: 77.3ms	remaining: 1.96s
# 38:	learn: 0.6151544	total: 79.3ms	remaining: 1.95s
# 39:	learn: 0.6134886	total: 81.3ms	remaining: 1.95s
# 40:	learn: 0.6117430	total: 83.3ms	remaining: 1.95s
# 41:	learn: 0.6106000	total: 85.3ms	remaining: 1.94s
# 42:	learn: 0.6092332	total: 87.2ms	remaining: 1.94s
# 43:	learn: 0.6074084	total: 89.2ms	remaining: 1.94s
# 44:	learn: 0.6061503	total: 91.1ms	remaining: 1.93s
# 45:	learn: 0.6043120	total: 93.1ms	remaining: 1.93s
# 46:	learn: 0.6031675	total: 95.4ms	remaining: 1.93s
# 47:	learn: 0.6012976	total: 97.9ms	remaining: 1.94s
# 48:	learn: 0.5996154	total: 100ms	remaining: 1.94s
# 49:	learn: 0.5975224	total: 102ms	remaining: 1.94s
# 50:	learn: 0.5959655	total: 104ms	remaining: 1.94s
# 51:	learn: 0.5943612	total: 106ms	remaining: 1.94s
# 52:	learn: 0.5924977	total: 108ms	remaining: 1.93s
# 53:	learn: 0.5911780	total: 110ms	remaining: 1.93s
# 54:	learn: 0.5892882	total: 112ms	remaining: 1.93s
# 55:	learn: 0.5878584	total: 114ms	remaining: 1.93s
# 56:	learn: 0.5858587	total: 117ms	remaining: 1.93s
# ------------------------------------------------------------------------------
# ------------------------------------------------------------------------------
# 'Tunning Data Report is Secured for this phase!!!'

# %% [markdown]
# #Result Analysis

# %%
import pandas as pd
import os
import glob


csv_files = glob.glob(os.path.join("/content/drive/MyDrive/Iqram Sir/Tinnitus/Features_CSV", "*.csv"))

final_dataset = pd.DataFrame()

for f in csv_files:
            df_temp = pd.read_csv(f)
            final_dataset = final_dataset.append(df_temp, ignore_index=True)

# %% [markdown]
# ##Sorting according to accuracy

# %%
final_dataset = final_dataset.sort_values("accurecy",ascending=False,kind="mergesort")
final_dataset = final_dataset.reset_index(drop = True)
final_dataset.head(50)
# Out:
#                                            model_name  \
# 0                     KNeighborsClassifier(n_jobs=-1)
# 1                            DecisionTreeClassifier()
# 2                                        GaussianNB()
# 3                     KNeighborsClassifier(n_jobs=-1)
# 4                            XGBClassifier(n_jobs=-1)
# 5                            XGBClassifier(n_jobs=-1)
# 6                            XGBClassifier(n_jobs=-1)
# 7                            XGBClassifier(n_jobs=-1)
# 8                            XGBClassifier(n_jobs=-1)
# 9                                        GaussianNB()
# 10                    KNeighborsClassifier(n_jobs=-1)
# 11                    KNeighborsClassifier(n_jobs=-1)
# 12                    KNeighborsClassifier(n_jobs=-1)
# 13                 AdaBoostClassifier(random_state=0)
# 14                                       GaussianNB()
# 15                                       GaussianNB()
# 16  RandomForestClassifier(n_jobs=-1, random_state=0)
# 17                                       GaussianNB()
# 18                                       GaussianNB()
# 19                                       GaussianNB()
# 20                           DecisionTreeClassifier()
# 21                 AdaBoostClassifier(random_state=0)
# 22                                       GaussianNB()
# 23     HistGradientBoostingClassifier(random_state=0)
# 24                                       GaussianNB()
# 25     HistGradientBoostingClassifier(random_state=0)
# 26                                       GaussianNB()
# 27     HistGradientBoostingClassifier(random_state=0)
# 28                                       GaussianNB()
# 29     HistGradientBoostingClassifier(random_state=0)
# 30                                       GaussianNB()
# 31     HistGradientBoostingClassifier(random_state=0)
# 32                                       GaussianNB()
# 33                    KNeighborsClassifier(n_jobs=-1)
# 34                           DecisionTreeClassifier()
# 35                 AdaBoostClassifier(random_state=0)
# 36                 AdaBoostClassifier(random_state=0)
# 37                    KNeighborsClassifier(n_jobs=-1)
# 38     HistGradientBoostingClassifier(random_state=0)
# 39                    KNeighborsClassifier(n_jobs=-1)
# 40                                       GaussianNB()
# 41                    KNeighborsClassifier(n_jobs=-1)
# 42                 AdaBoostClassifier(random_state=0)
# 43     HistGradientBoostingClassifier(random_state=0)
# 44                                       GaussianNB()
# 45                 AdaBoostClassifier(random_state=0)
# 46         GradientBoostingClassifier(random_state=0)
# 47     HistGradientBoostingClassifier(random_state=0)
# 48                                       GaussianNB()
# 49                                       GaussianNB()
#
#                                     tunning_type  accurecy  scaled_accuracy  \
# 0        Smote : All   ; Scaling : All(Standard)  0.794872             0.79
# 1          Smote : All   ; Scaling : All(MinMax)  0.794872             0.79
# 2   Smote : NO    ; Scaling : All Data(Standard)  0.781250             0.78
# 3          Smote : All   ; Scaling : All(MinMax)  0.769231             0.77
# 4     Smote : NO    ; Scaling : All Data(MinMax)  0.750000             0.75
# 5     Smote : NO    ; Scaling : All Data(MinMax)  0.750000             0.75
# 6     Smote : NO    ; Scaling : All Data(MinMax)  0.750000             0.75
# 7     Smote : NO    ; Scaling : All Data(MinMax)  0.750000             0.75
# 8     Smote : NO    ; Scaling : All Data(MinMax)  0.750000             0.75
# 9        Smote : All   ; Scaling : All(Standard)  0.743590             0.74
# 10       Smote : All   ; Scaling : All(Standard)  0.743590             0.74
# 11       Smote : All   ; Scaling : All(Standard)  0.743590             0.74
# 12       Smote : All   ; Scaling : All(Standard)  0.743590             0.74
# 13                  Smote : Train ; Scaling : NO  0.718750             0.72
# 14                  Smote : NO    ; Scaling : NO  0.718750             0.72
# 15                  Smote : Train ; Scaling : NO  0.718750             0.72
# 16    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 17                  Smote : NO    ; Scaling : NO  0.718750             0.72
# 18  Smote : NO    ; Scaling : All Data(Standard)  0.718750             0.72
# 19                  Smote : Train ; Scaling : NO  0.718750             0.72
# 20    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 21    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 22                  Smote : NO    ; Scaling : NO  0.718750             0.72
# 23    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 24  Smote : NO    ; Scaling : All Data(Standard)  0.718750             0.72
# 25    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 26  Smote : NO    ; Scaling : All Data(Standard)  0.718750             0.72
# 27    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 28  Smote : NO    ; Scaling : All Data(Standard)  0.718750             0.72
# 29    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 30  Smote : NO    ; Scaling : All Data(Standard)  0.718750             0.72
# 31    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 32  Smote : NO    ; Scaling : All Data(Standard)  0.718750             0.72
# 33    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 34    Smote : NO    ; Scaling : All Data(MinMax)  0.718750             0.72
# 35                  Smote : ALL   ; Scaling : NO  0.717949             0.72
# 36         Smote : All   ; Scaling : All(MinMax)  0.717949             0.72
# 37       Smote : All   ; Scaling : All(Standard)  0.717949             0.72
# 38         Smote : All   ; Scaling : All(MinMax)  0.717949             0.72
# 39       Smote : All   ; Scaling : All(Standard)  0.717949             0.72
# 40                  Smote : ALL   ; Scaling : NO  0.717949             0.72
# 41       Smote : All   ; Scaling : All(Standard)  0.717949             0.72
# 42                  Smote : ALL   ; Scaling : NO  0.692308             0.69
# 43                  Smote : ALL   ; Scaling : NO  0.692308             0.69
# 44                  Smote : ALL   ; Scaling : NO  0.692308             0.69
# 45         Smote : All   ; Scaling : All(MinMax)  0.692308             0.69
# 46         Smote : All   ; Scaling : All(MinMax)  0.692308             0.69
# 47                  Smote : ALL   ; Scaling : NO  0.692308             0.69
# 48                  Smote : ALL   ; Scaling : NO  0.692308             0.69
# 49       Smote : All   ; Scaling : All(Standard)  0.692308             0.69
#
#    feature_selection_method  number_of_features
# 0             list_of_feat2                  20
# 1                Sequential                  20
# 2                     ANOVA                  20
# 3             list_of_feat2                  20
# 4                     ANOVA                  15
# 5                   Pearson                  15
# 6                   Pearson                  20
# 7                   Pearson                  25
# 8                   Pearson                  30
# 9             list_of_feat2                  20
# 10                    ANOVA                  20
# 11                  Pearson                  15
# 12                  Pearson                  30
# 13            list_of_feat2                  20
# 14            list_of_feat2                  20
# 15            list_of_feat2                  20
# 16            list_of_feat3                  17
# 17            list_of_feat3                  17
# 18            list_of_feat3                  17
# 19            list_of_feat3                  17
# 20                    ANOVA                  25
# 21                    ANOVA                  20
# 22                    ANOVA                  20
# 23                    ANOVA                  15
# 24                    ANOVA                  15
# 25                  Pearson                  15
# 26                  Pearson                  15
# 27                  Pearson                  20
# 28                  Pearson                  20
# 29                  Pearson                  25
# 30                  Pearson                  25
# 31                  Pearson                  30
# 32                  Pearson                  30
# 33               Sequential                  30
# 34               Sequential                  20
# 35                    ANOVA                  25
# 36                    ANOVA                  20
# 37                    ANOVA                  15
# 38                  Pearson                  20
# 39                  Pearson                  20
# 40                  Pearson                  20
# 41                  Pearson                  25
# 42            list_of_feat2                  20
# 43            list_of_feat2                  20
# 44            list_of_feat2                  20
# 45            list_of_feat3                  17
# 46            list_of_feat3                  17
# 47            list_of_feat3                  17
# 48            list_of_feat3                  17
# 49            list_of_feat3                  17

# %% [markdown]
# ##Saving

# %%
final_dataset.to_csv("/content/drive/MyDrive/Iqram Sir/Tinnitus/FSR.csv",index=False)

# %%
final_dataset.to_csv("FSR_list_2_3.csv",index=False)

# %%
final_dataset.head(10)
# Out:
#                            model_name  \
# 0     KNeighborsClassifier(n_jobs=-1)
# 1     KNeighborsClassifier(n_jobs=-1)
# 2                        GaussianNB()
# 3     KNeighborsClassifier(n_jobs=-1)
# 4  AdaBoostClassifier(random_state=0)
# 5            XGBClassifier(n_jobs=-1)
# 6                        GaussianNB()
# 7  AdaBoostClassifier(random_state=0)
# 8                        GaussianNB()
# 9                        GaussianNB()
#
#                                    tunning_type  accurecy  scaled_accuracy  \
# 0       Smote : All   ; Scaling : All(Standard)  0.846154             0.85
# 1       Smote : All   ; Scaling : All(Standard)  0.794872             0.79
# 2  Smote : NO    ; Scaling : All Data(Standard)  0.781250             0.78
# 3         Smote : All   ; Scaling : All(MinMax)  0.769231             0.77
# 4         Smote : All   ; Scaling : All(MinMax)  0.769231             0.77
# 5    Smote : NO    ; Scaling : All Data(MinMax)  0.750000             0.75
# 6       Smote : All   ; Scaling : All(Standard)  0.743590             0.74
# 7                  Smote : Train ; Scaling : NO  0.718750             0.72
# 8                  Smote : NO    ; Scaling : NO  0.718750             0.72
# 9                  Smote : Train ; Scaling : NO  0.718750             0.72
#
#   feature_selection_method  number_of_features
# 0                    ANOVA                  20
# 1            list_of_feat2                  20
# 2                    ANOVA                  20
# 3            list_of_feat2                  20
# 4                    ANOVA                  20
# 5                    ANOVA                  15
# 6            list_of_feat2                  20
# 7            list_of_feat2                  20
# 8            list_of_feat2                  20
# 9            list_of_feat2                  20
