# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/ARC_Machine/blob/main/WOMAC_Reg_Version_210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("/content/KOA_EMG_WOMAC__2022.08.22_Final_W-tempo-spatial.csv")

# %%
dataset.head(10)
# Out:
#    Patient ID  WOMAC_total WOMAC Severity  CCI_TA-RF  CCI_G-MH  CCI_TA-MH  \
# 0       10193           40       Moderate      144.9      66.0      108.1
# 1       10193           42       Moderate       99.1     123.6       98.9
# 2       11407           42       Moderate       90.4     160.1       80.7
# 3       11407           41       Moderate      146.6     196.2      136.4
# 4       12435           23           Mild      147.9     153.5       85.9
# 5       12435           47       Moderate       99.4      55.4       93.6
# 6       12521           19           Mild       90.0      91.0       92.0
# 7       12521           53       Moderate      133.5      93.6      121.1
# 8       12687           74         Severe      193.3     130.3      207.0
# 9       12687           74         Severe      129.5     115.1       88.9
#
#    CCI_G-RF  CCI_TA-G  CCI_MH-RF  CCI_L-H  ...   Lyapunov_TIBIALIS ANT  \
# 0      86.2     171.7       87.1    183.8  ...                    0.40
# 1     123.6     109.4      145.9    215.6  ...                    0.30
# 2     164.8      88.5      110.4    217.2  ...                    0.20
# 3     184.8     123.0      106.3    293.3  ...                    0.30
# 4     305.4      90.3       40.4    268.2  ...                    0.30
# 5      58.7     150.9      108.4    145.9  ...                    0.30
# 6      88.7     115.0      136.7    174.1  ...                    0.40
# 7     100.7     146.5      100.4    214.5  ...                    0.30
# 8     129.6     162.9      140.1    295.2  ...                    0.31
# 9     180.9     103.8       79.0    229.5  ...                    0.30
#
#    Stance_CCI_TA-RF  Stance_CCI_G-MH  Stance_CCI_TA-G  Swing_CCI_TA-RF  \
# 0        115.016739        82.560104       129.779021       212.427472
# 1         80.799114       118.800065        87.596328       120.058278
# 2         64.522568       185.837798        53.250781       118.951867
# 3        157.259039       213.969267       126.550560       134.834096
# 4        158.726742       198.202890        94.353370       135.926913
# 5        147.257611        72.130138       197.046837        48.532762
# 6         86.971580       107.723821       106.343048        93.422362
# 7        112.746870       109.750454       131.151480       156.402708
# 8        223.637121       142.868454       166.702324       155.574614
# 9        139.496753       123.489941       101.890803       118.112704
#
#    Swing_CCI_G-MH  Swing_CCI_TA-G  swing/stance_cci(TA_RF)  \
# 0       35.934817      266.326016                 1.846927
# 1      131.061267      145.432434                 1.485886
# 2      119.206854      144.415087                 1.843570
# 3      168.262739      117.370956                 0.857401
# 4       82.676272       83.944362                 0.856358
# 5       29.851684       80.509844                 0.329577
# 6       64.138358      128.642708                 1.074171
# 7       68.811402      170.867378                 1.387202
# 8      109.404210      155.958741                 0.695656
# 9      102.404559      106.992896                 0.846706
#
#    swing/stance_cci(G-MH)  swing/stance_CCI(TA-G)
# 0                0.435256                2.052150
# 1                1.103209                1.660257
# 2                0.641456                2.711981
# 3                0.786387                0.927463
# 4                0.417129                0.889681
# 5                0.413859                0.408582
# 6                0.595396                1.209696
# 7                0.626981                1.302825
# 8                0.765769                0.935552
# 9                0.829254                1.050074
#
# [10 rows x 87 columns]

# %%
dataset.shape
# Out:
# (150, 87)

# %%
X = dataset.iloc[:,3:]
y = dataset.iloc[:, 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)

# %%
print(y_pred.shape)
# Out:
# (30,)

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_score(y_test,y_pred)
# Out:
# -3.2229507667144723

# %%
r_sq = lin_reg.score(X, y)
print(r_sq)
# Out:
# -0.21246213972070427

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_pred, color = "red")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
pred_y_df=pd.DataFrame(
    {
        "Actual Value":y_test,
        "Predicted Value":y_pred,
        "Difference":y_test-y_pred
    }
)

pred_y_df
# Out:
#      Actual Value  Predicted Value  Difference
# 114            39        65.233519  -26.233519
# 62             50        48.426450    1.573550
# 33             59        44.505246   14.494754
# 107            35        31.233082    3.766918
# 7              53        40.857177   12.142823
# 100            47        24.426368   22.573632
# 40             72        85.262328  -13.262328
# 86             53        40.600565   12.399435
# 76             72        34.208940   37.791060
# 71             27        56.729162  -29.729162
# 134             1       164.834852 -163.834852
# 51             83        52.652487   30.347513
# 73             55        63.616926   -8.616926
# 54             70        56.897277   13.102723
# 63             48        65.795816  -17.795816
# 37             70        60.100188    9.899812
# 78             66        55.445916   10.554084
# 90             38       -15.217341   53.217341
# 45             66        76.171029  -10.171029
# 16             45        23.365377   21.634623
# 121            25        79.199738  -54.199738
# 66             24        38.129235  -14.129235
# 24             23        29.185728   -6.185728
# 8              74        67.654838    6.345162
# 126            52        67.983226  -15.983226
# 22             53        -6.505490   59.505490
# 44             70        83.589608  -13.589608
# 97             44        46.292812   -2.292812
# 93             47        46.766615    0.233385
# 26             28        -3.073442   31.073442

# %%
# The coefficients
print("Coefficients: \n", lin_reg.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [0.745741 0.043803 0.041458 -0.035532 -1.341240 -0.055975 0.086170
#  -0.200939 -0.157412 1.156769 -0.342394 -2.073057 67.673645 -6.866082
#  -1.898068 -4.869184 56.036273 -1.898068 -3.934234 56.036273 106.287650
#  2.041575 0.362947 -2.622423 1.461746 0.057689 0.057359 0.036775 0.127545
#  0.070280 0.046322 -0.038280 0.310042 0.012591 -0.011037 -0.075055
#  0.182497 -125.431508 728.431058 1846.146482 992.237677 -1307.455364
#  -1764.917757 470.424144 434.142199 -1273.580935 68.954092 -475.836420
#  -206.141593 338.647107 -371.429526 -342.410275 196.976086 -149.166566
#  940.394831 5.545335 8.179720 0.856380 -19.927624 -16.242233 -12.270792
#  43.273027 -24.303719 1.192128 -0.788952 -11.098277 6.178315 2.322192
#  0.974863 -2.045203 1.654715 34.540356 -27.262986 -49.941693 -1.194102
#  -0.416395 -0.118166 0.898435 -0.362769 -0.096443 0.494458 2.868335
#  1.406217 4.162823]
# Mean squared error: 1477.32
# Coefficient of determination: -3.22

# %%
import seaborn as sns


scatter_poly2 = sns.lmplot(
    data = pred_y_df, 
    x = "Actual Value",
    y = "Predicted Value",
    order = 2
)

# %%
sns.regplot(x="Actual Value", y="Predicted Value", data=pred_y_df);

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error
from math import sqrt

# %matplotlib inline


np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# Increases the size of sns plots
sns.set(rc={'figure.figsize':(12,10)})

# %%
raw_data = pd.read_csv("/content/drive/MyDrive/Iqram Sir/Latest/KOA_EMG_WOMAC__2022.08.16_Final_WO-tempo-spatial.csv")

# print the shape
print(raw_data.shape)

#runs the first 5 rows
raw_data.head()
# Out:
# (150, 785)
#    Patient ID  WOMAC_total WOMAC Severity  CCI_TA-RF  CCI_G-MH  CCI_TA-MH  \
# 0       10193           40       Moderate      144.9      66.0      108.1
# 1       10193           42       Moderate       99.1     123.6       98.9
# 2       11407           42       Moderate       90.4     160.1       80.7
# 3       11407           41       Moderate      146.6     196.2      136.4
# 4       12435           23           Mild      147.9     153.5       85.9
#
#    CCI_G-RF  CCI_TA-G  CCI_MH-RF  CCI_L-H  ...    TA-G-100  Stance_CCI_TA-RF  \
# 0      86.2     171.7       87.1    183.8  ...  234.689409        115.016739
# 1     123.6     109.4      145.9    215.6  ...  130.854095         80.799114
# 2     164.8      88.5      110.4    217.2  ...  109.781099         64.522568
# 3     184.8     123.0      106.3    293.3  ...  117.902928        157.259039
# 4     305.4      90.3       40.4    268.2  ...   76.648348        158.726742
#
#    Stance_CCI_G-MH  Stance_CCI_TA-G  Swing_CCI_TA-RF  Swing_CCI_G-MH  \
# 0        82.560104       129.779021       212.427472       35.934817
# 1       118.800065        87.596328       120.058278      131.061267
# 2       185.837798        53.250781       118.951867      119.206854
# 3       213.969267       126.550560       134.834096      168.262739
# 4       198.202890        94.353370       135.926913       82.676272
#
#    Swing_CCI_TA-G  swing/stance_cci(TA_RF)  swing/stance_cci(G-MH)  \
# 0      266.326016                 1.846927                0.435256
# 1      145.432434                 1.485886                1.103209
# 2      144.415087                 1.843570                0.641456
# 3      117.370956                 0.857401                0.786387
# 4       83.944362                 0.856358                0.417129
#
#    swing/stance_CCI(TA-G)
# 0                2.052150
# 1                1.660257
# 2                2.711981
# 3                0.927463
# 4                0.889681
#
# [5 rows x 785 columns]

# %%
# Checking for null values

raw_data.isnull().sum()
# Out:
# Patient ID                 0
# WOMAC_total                0
# WOMAC Severity             0
# CCI_TA-RF                  0
# CCI_G-MH                   0
#                           ..
# Swing_CCI_G-MH             0
# Swing_CCI_TA-G             0
# swing/stance_cci(TA_RF)    0
# swing/stance_cci(G-MH)     0
# swing/stance_CCI(TA-G)     0
# Length: 785, dtype: int64

# %%
# Investigate all the elements whithin each Feature 
for column in raw_data:
    unique_vals = np.unique(raw_data[column])
    nr_values = len(unique_vals)
    if nr_values < 10:
        print('The number of values for feature {} :{} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for feature {} :{}'.format(column, nr_values))
# Out:
# The number of values for feature Patient ID :89
# The number of values for feature WOMAC_total :55
# The number of values for feature WOMAC Severity :3 -- ['Mild' 'Moderate' 'Severe']
# The number of values for feature CCI_TA-RF :147
# The number of values for feature CCI_G-MH :144
# The number of values for feature CCI_TA-MH :146
# The number of values for feature CCI_G-RF :140
# The number of values for feature CCI_TA-G :144
# The number of values for feature CCI_MH-RF :148
# The number of values for feature CCI_L-H :144
# The number of values for feature CCI_F-B :148
# The number of values for feature  Max_RECTUS :1 -- [100]
# The number of values for feature  Max_MEDIAL HAM :1 -- [100]
# The number of values for feature  Max_GASTROCNEMIUS :1 -- [100]
# The number of values for feature  Max_TIBIALIS ANT :1 -- [100]
# The number of values for feature  Min_RECTUS :139
# The number of values for feature  Min_MEDIAL HAM :141
# The number of values for feature  Min_GASTROCNEMIUS :133
# The number of values for feature  Min_TIBIALIS ANT :137
# The number of values for feature  Max T_RECTUS :55
# The number of values for feature  Max T_MEDIAL HAM :48
# The number of values for feature  Max T_GASTROCNEMIUS :66
# The number of values for feature  Max T_TIBIALIS ANT :61
# The number of values for feature  Min T_RECTUS :54
# The number of values for feature  Min T_MEDIAL HAM :62
# The number of values for feature  Min T_GASTROCNEMIUS :53
# The number of values for feature  Min T_TIBIALIS ANT :64
# The number of values for feature Max-Min T_RECTUS :83
# The number of values for feature Max-Min T_MEDIAL HAM :74
# The number of values for feature  Max-Min T_GASTROCNEMIUS :81
# The number of values for feature  Max-Min T_TIBIALIS ANT :86
# The number of values for feature  Integral_RECTUS :150
# The number of values for feature  Integral_MEDIAL HAM :150
# The number of values for feature  Integral_GASTROCNEMIUS :150
# The number of values for feature  Integral_TIBIALIS ANT :150
# The number of values for feature Average_Integral :150
# The number of values for feature Average_Integral_L :150
# The number of values for feature Average_Integral_U :150
# The number of values for feature Average_Integral_F :150
# The number of values for feature Average_Integral_B :150
# The number of values for feature  Area_RECTUS :150
# The number of values for feature  Area_MEDIAL HAM :150
# The number of values for feature  Area_GASTROCNEMIUS :150
# The number of values for feature  Area_TIBIALIS ANT :150
# The number of values for feature Average_AUC :150
# The number of values for feature Average_AUC_L :150
# The number of values for feature Average_AUC_U :150
# The number of values for feature Average_AUC_F :150
# The number of values for feature Average_AUC_B :150
# The number of values for feature  Lin_reg_RECTUS :44
# The number of values for feature  Lin_reg_MEDIAL HAM :39
# The number of values for feature  Lin_reg_GASTROCNEMIUS :50
# The number of values for feature  Lin_reg_TIBIALIS ANT :48
# The number of values for feature  Skew_RECTUS :79
# The number of values for feature  Skew_MEDIAL HAM :68
# The number of values for feature  Skew_GASTROCNEMIUS :76
# The number of values for feature  Skew_TIBIALIS ANT :67
# The number of values for feature  Kurtosis_RECTUS :96
# The number of values for feature  Kurtosis_MEDIAL HAM :85
# The number of values for feature  Kurtosis_GASTROCNEMIUS :95
# The number of values for feature  Kurtosis_TIBIALIS ANT :82
# The number of values for feature  Stddev_RECTUS :121
# The number of values for feature  Stddev_MEDIAL HAM :126
# The number of values for feature  Stddev_GASTROCNEMIUS :120
# The number of values for feature  Stddev_TIBIALIS ANT :126
# The number of values for feature  Lyapunov_RECTUS :27
# The number of values for feature  Lyapunov_MEDIAL HAM :27
# The number of values for feature  Lyapunov_GASTROCNEMIUS :30
# The number of values for feature  Lyapunov_TIBIALIS ANT :29
# The number of values for feature G0 :150
# The number of values for feature G1 :149
# The number of values for feature G2 :150
# The number of values for feature G3 :150
# The number of values for feature G4 :150
# The number of values for feature G5 :149
# The number of values for feature G6 :150
# The number of values for feature G7 :150
# The number of values for feature G8 :150
# The number of values for feature G9 :149
# The number of values for feature G10 :149
# The number of values for feature G11 :150
# The number of values for feature G12 :147
# The number of values for feature G13 :150
# The number of values for feature G14 :146
# The number of values for feature G15 :147
# The number of values for feature G16 :148
# The number of values for feature G17 :148
# The number of values for feature G18 :149
# The number of values for feature G19 :149
# The number of values for feature G20 :146
# The number of values for feature G21 :147
# The number of values for feature G22 :148
# The number of values for feature G23 :150
# The number of values for feature G24 :150
# The number of values for feature G25 :150
# The number of values for feature G26 :147
# The number of values for feature G27 :150
# The number of values for feature G28 :150
# The number of values for feature G29 :150
# The number of values for feature G30 :150
# The number of values for feature G31 :150
# The number of values for feature G32 :150
# The number of values for feature G33 :150
# The number of values for feature G34 :150
# The number of values for feature G35 :150
# The number of values for feature G36 :150
# The number of values for feature G37 :149
# The number of values for feature G38 :150
# The number of values for feature G39 :150
# The number of values for feature G40 :150
# The number of values for feature G41 :148
# The number of values for feature G42 :150
# The number of values for feature G43 :150
# The number of values for feature G44 :146
# The number of values for feature G45 :149
# The number of values for feature G46 :146
# The number of values for feature G47 :148
# The number of values for feature G48 :147
# The number of values for feature G49 :147
# The number of values for feature G50 :146
# The number of values for feature G51 :145
# The number of values for feature G52 :144
# The number of values for feature G53 :149
# The number of values for feature G54 :147
# The number of values for feature G55 :146
# The number of values for feature G56 :149
# The number of values for feature G57 :147
# The number of values for feature G58 :150
# The number of values for feature G59 :150
# The number of values for feature G60 :150
# The number of values for feature G61 :150
# The number of values for feature G62 :150
# The number of values for feature G63 :149
# The number of values for feature G64 :150
# The number of values for feature G65 :150
# The number of values for feature G66 :150
# The number of values for feature G67 :150
# The number of values for feature G68 :150
# The number of values for feature G69 :150
# The number of values for feature G70 :150
# The number of values for feature G71 :150
# The number of values for feature G72 :150
# The number of values for feature G73 :149
# The number of values for feature G74 :149
# The number of values for feature G75 :150
# The number of values for feature G76 :150
# The number of values for feature G77 :150
# The number of values for feature G78 :150
# The number of values for feature G79 :150
# The number of values for feature G80 :150
# The number of values for feature G81 :150
# The number of values for feature G82 :150
# The number of values for feature G83 :150
# The number of values for feature G84 :150
# The number of values for feature G85 :150
# The number of values for feature G86 :150
# The number of values for feature G87 :150
# The number of values for feature G88 :150
# The number of values for feature G89 :150
# The number of values for feature G90 :150
# The number of values for feature G91 :150
# The number of values for feature G92 :150
# The number of values for feature G93 :150
# The number of values for feature G94 :150
# The number of values for feature G95 :150
# The number of values for feature G96 :150
# The number of values for feature G97 :150
# The number of values for feature G98 :149
# The number of values for feature G99 :149
# The number of values for feature G100 :149
# The number of values for feature MH0 :146
# The number of values for feature MH1 :147
# The number of values for feature MH2 :148
# The number of values for feature MH3 :150
# The number of values for feature MH4 :144
# The number of values for feature MH5 :149
# The number of values for feature MH6 :148
# The number of values for feature MH7 :146
# The number of values for feature MH8 :147
# The number of values for feature MH9 :147
# The number of values for feature MH10 :146
# The number of values for feature MH11 :138
# The number of values for feature MH12 :142
# The number of values for feature MH13 :145
# The number of values for feature MH14 :144
# The number of values for feature MH15 :141
# The number of values for feature MH16 :143
# The number of values for feature MH17 :148
# The number of values for feature MH18 :147
# The number of values for feature MH19 :147
# The number of values for feature MH20 :148
# The number of values for feature MH21 :150
# The number of values for feature MH22 :150
# The number of values for feature MH23 :150
# The number of values for feature MH24 :149
# The number of values for feature MH25 :149
# The number of values for feature MH26 :150
# The number of values for feature MH27 :148
# The number of values for feature MH28 :150
# The number of values for feature MH29 :150
# The number of values for feature MH30 :150
# The number of values for feature MH31 :150
# The number of values for feature MH32 :150
# The number of values for feature MH33 :150
# The number of values for feature MH34 :150
# The number of values for feature MH35 :150
# The number of values for feature MH36 :150
# The number of values for feature MH37 :150
# The number of values for feature MH38 :150
# The number of values for feature MH39 :150
# The number of values for feature MH40 :150
# The number of values for feature MH41 :150
# The number of values for feature MH42 :150
# The number of values for feature MH43 :150
# The number of values for feature MH44 :150
# The number of values for feature MH45 :150
# The number of values for feature MH46 :150
# The number of values for feature MH47 :150
# The number of values for feature MH48 :150
# The number of values for feature MH49 :150
# The number of values for feature MH50 :150
# The number of values for feature MH51 :150
# The number of values for feature MH52 :150
# The number of values for feature MH53 :150
# The number of values for feature MH54 :150
# The number of values for feature MH55 :150
# The number of values for feature MH56 :150
# The number of values for feature MH57 :150
# The number of values for feature MH58 :150
# The number of values for feature MH59 :150
# The number of values for feature MH60 :150
# The number of values for feature MH61 :150
# The number of values for feature MH62 :150
# The number of values for feature MH63 :150
# The number of values for feature MH64 :150
# The number of values for feature MH65 :150
# The number of values for feature MH66 :150
# The number of values for feature MH67 :150
# The number of values for feature MH68 :148
# The number of values for feature MH69 :150
# The number of values for feature MH70 :150
# The number of values for feature MH71 :150
# The number of values for feature MH72 :150
# The number of values for feature MH73 :150
# The number of values for feature MH74 :150
# The number of values for feature MH75 :150
# The number of values for feature MH76 :148
# The number of values for feature MH77 :150
# The number of values for feature MH78 :150
# The number of values for feature MH79 :149
# The number of values for feature MH80 :150
# The number of values for feature MH81 :150
# The number of values for feature MH82 :150
# The number of values for feature MH83 :150
# The number of values for feature MH84 :150
# The number of values for feature MH85 :150
# The number of values for feature MH86 :150
# The number of values for feature MH87 :150
# The number of values for feature MH88 :149
# The number of values for feature MH89 :150
# The number of values for feature MH90 :150
# The number of values for feature MH91 :150
# The number of values for feature MH92 :150
# The number of values for feature MH93 :150
# The number of values for feature MH94 :150
# The number of values for feature MH95 :150
# The number of values for feature MH96 :150
# The number of values for feature MH97 :150
# The number of values for feature MH98 :149
# The number of values for feature MH99 :148
# The number of values for feature MH100 :148
# The number of values for feature RF0 :148
# The number of values for feature RF1 :150
# The number of values for feature RF2 :150
# The number of values for feature RF3 :150
# The number of values for feature RF4 :150
# The number of values for feature RF5 :148
# The number of values for feature RF6 :149
# The number of values for feature RF7 :150
# The number of values for feature RF8 :148
# The number of values for feature RF9 :150
# The number of values for feature RF10 :147
# The number of values for feature RF11 :146
# The number of values for feature RF12 :145
# The number of values for feature RF13 :143
# The number of values for feature RF14 :145
# The number of values for feature RF15 :144
# The number of values for feature RF16 :148
# The number of values for feature RF17 :144
# The number of values for feature RF18 :147
# The number of values for feature RF19 :146
# The number of values for feature RF20 :147
# The number of values for feature RF21 :146
# The number of values for feature RF22 :148
# The number of values for feature RF23 :148
# The number of values for feature RF24 :150
# The number of values for feature RF25 :148
# The number of values for feature RF26 :145
# The number of values for feature RF27 :150
# The number of values for feature RF28 :148
# The number of values for feature RF29 :146
# The number of values for feature RF30 :150
# The number of values for feature RF31 :148
# The number of values for feature RF32 :150
# The number of values for feature RF33 :147
# The number of values for feature RF34 :150
# The number of values for feature RF35 :150
# The number of values for feature RF36 :150
# The number of values for feature RF37 :150
# The number of values for feature RF38 :150
# The number of values for feature RF39 :150
# The number of values for feature RF40 :150
# The number of values for feature RF41 :150
# The number of values for feature RF42 :150
# The number of values for feature RF43 :150
# The number of values for feature RF44 :149
# The number of values for feature RF45 :150
# The number of values for feature RF46 :150
# The number of values for feature RF47 :150
# The number of values for feature RF48 :149
# The number of values for feature RF49 :150
# The number of values for feature RF50 :150
# The number of values for feature RF51 :150
# The number of values for feature RF52 :150
# The number of values for feature RF53 :150
# The number of values for feature RF54 :150
# The number of values for feature RF55 :150
# The number of values for feature RF56 :150
# The number of values for feature RF57 :149
# The number of values for feature RF58 :150
# The number of values for feature RF59 :150
# The number of values for feature RF60 :149
# The number of values for feature RF61 :150
# The number of values for feature RF62 :150
# The number of values for feature RF63 :150
# The number of values for feature RF64 :149
# The number of values for feature RF65 :146
# The number of values for feature RF66 :150
# The number of values for feature RF67 :150
# The number of values for feature RF68 :150
# The number of values for feature RF69 :150
# The number of values for feature RF70 :150
# The number of values for feature RF71 :150
# The number of values for feature RF72 :150
# The number of values for feature RF73 :150
# The number of values for feature RF74 :147
# The number of values for feature RF75 :150
# The number of values for feature RF76 :150
# The number of values for feature RF77 :150
# The number of values for feature RF78 :150
# The number of values for feature RF79 :149
# The number of values for feature RF80 :150
# The number of values for feature RF81 :150
# The number of values for feature RF82 :150
# The number of values for feature RF83 :150
# The number of values for feature RF84 :150
# The number of values for feature RF85 :150
# The number of values for feature RF86 :150
# The number of values for feature RF87 :150
# The number of values for feature RF88 :150
# The number of values for feature RF89 :150
# The number of values for feature RF90 :150
# The number of values for feature RF91 :150
# The number of values for feature RF92 :150
# The number of values for feature RF93 :150
# The number of values for feature RF94 :150
# The number of values for feature RF95 :150
# The number of values for feature RF96 :150
# The number of values for feature RF97 :149
# The number of values for feature RF98 :150
# The number of values for feature RF99 :150
# The number of values for feature RF100 :150
# The number of values for feature TA0 :150
# The number of values for feature TA1 :150
# The number of values for feature TA2 :150
# The number of values for feature TA3 :150
# The number of values for feature TA4 :150
# The number of values for feature TA5 :150
# The number of values for feature TA6 :150
# The number of values for feature TA7 :150
# The number of values for feature TA8 :147
# The number of values for feature TA9 :144
# The number of values for feature TA10 :146
# The number of values for feature TA11 :148
# The number of values for feature TA12 :143
# The number of values for feature TA13 :146
# The number of values for feature TA14 :146
# The number of values for feature TA15 :147
# The number of values for feature TA16 :147
# The number of values for feature TA17 :149
# The number of values for feature TA18 :150
# The number of values for feature TA19 :149
# The number of values for feature TA20 :150
# The number of values for feature TA21 :147
# The number of values for feature TA22 :150
# The number of values for feature TA23 :150
# The number of values for feature TA24 :149
# The number of values for feature TA25 :150
# The number of values for feature TA26 :148
# The number of values for feature TA27 :149
# The number of values for feature TA28 :149
# The number of values for feature TA29 :150
# The number of values for feature TA30 :149
# The number of values for feature TA31 :150
# The number of values for feature TA32 :150
# The number of values for feature TA33 :150
# The number of values for feature TA34 :150
# The number of values for feature TA35 :150
# The number of values for feature TA36 :150
# The number of values for feature TA37 :150
# The number of values for feature TA38 :149
# The number of values for feature TA39 :150
# The number of values for feature TA40 :150
# The number of values for feature TA41 :150
# The number of values for feature TA42 :150
# The number of values for feature TA43 :150
# The number of values for feature TA44 :150
# The number of values for feature TA45 :149
# The number of values for feature TA46 :150
# The number of values for feature TA47 :150
# The number of values for feature TA48 :150
# The number of values for feature TA49 :150
# The number of values for feature TA50 :150
# The number of values for feature TA51 :150
# The number of values for feature TA52 :150
# The number of values for feature TA53 :150
# The number of values for feature TA54 :150
# The number of values for feature TA55 :150
# The number of values for feature TA56 :150
# The number of values for feature TA57 :150
# The number of values for feature TA58 :149
# The number of values for feature TA59 :150
# The number of values for feature TA60 :149
# The number of values for feature TA61 :150
# The number of values for feature TA62 :149
# The number of values for feature TA63 :150
# The number of values for feature TA64 :150
# The number of values for feature TA65 :149
# The number of values for feature TA66 :150
# The number of values for feature TA67 :147
# The number of values for feature TA68 :150
# The number of values for feature TA69 :150
# The number of values for feature TA70 :150
# The number of values for feature TA71 :150
# The number of values for feature TA72 :149
# The number of values for feature TA73 :149
# The number of values for feature TA74 :150
# The number of values for feature TA75 :145
# The number of values for feature TA76 :148
# The number of values for feature TA77 :146
# The number of values for feature TA78 :143
# The number of values for feature TA79 :149
# The number of values for feature TA80 :145
# The number of values for feature TA81 :149
# The number of values for feature TA82 :146
# The number of values for feature TA83 :150
# The number of values for feature TA84 :149
# The number of values for feature TA85 :150
# The number of values for feature TA86 :150
# The number of values for feature TA87 :149
# The number of values for feature TA88 :150
# The number of values for feature TA89 :150
# The number of values for feature TA90 :150
# The number of values for feature TA91 :150
# The number of values for feature TA92 :150
# The number of values for feature TA93 :150
# The number of values for feature TA94 :150
# The number of values for feature TA95 :150
# The number of values for feature TA96 :150
# The number of values for feature TA97 :150
# The number of values for feature TA98 :150
# The number of values for feature TA99 :150
# The number of values for feature TA100 :150
# The number of values for feature TA-RF-0 :150
# The number of values for feature TA-RF-1 :150
# The number of values for feature TA-RF-2 :150
# The number of values for feature TA-RF-3 :150
# The number of values for feature TA-RF-4 :150
# The number of values for feature TA-RF-5 :150
# The number of values for feature TA-RF-6 :150
# The number of values for feature TA-RF-7 :150
# The number of values for feature TA-RF-8 :150
# The number of values for feature TA-RF-9 :150
# The number of values for feature TA-RF-10 :150
# The number of values for feature TA-RF-11 :150
# The number of values for feature TA-RF-12 :150
# The number of values for feature TA-RF-13 :150
# The number of values for feature TA-RF-14 :150
# The number of values for feature TA-RF-15 :150
# The number of values for feature TA-RF-16 :150
# The number of values for feature TA-RF-17 :150
# The number of values for feature TA-RF-18 :150
# The number of values for feature TA-RF-19 :150
# The number of values for feature TA-RF-20 :150
# The number of values for feature TA-RF-21 :150
# The number of values for feature TA-RF-22 :150
# The number of values for feature TA-RF-23 :150
# The number of values for feature TA-RF-24 :150
# The number of values for feature TA-RF-25 :150
# The number of values for feature TA-RF-26 :150
# The number of values for feature TA-RF-27 :150
# The number of values for feature TA-RF-28 :150
# The number of values for feature TA-RF-29 :150
# The number of values for feature TA-RF-30 :150
# The number of values for feature TA-RF-31 :150
# The number of values for feature TA-RF-32 :150
# The number of values for feature TA-RF-33 :150
# The number of values for feature TA-RF-34 :150
# The number of values for feature TA-RF-35 :150
# The number of values for feature TA-RF-36 :150
# The number of values for feature TA-RF-37 :150
# The number of values for feature TA-RF-38 :150
# The number of values for feature TA-RF-39 :150
# The number of values for feature TA-RF-40 :150
# The number of values for feature TA-RF-41 :150
# The number of values for feature TA-RF-42 :150
# The number of values for feature TA-RF-43 :150
# The number of values for feature TA-RF-44 :150
# The number of values for feature TA-RF-45 :150
# The number of values for feature TA-RF-46 :150
# The number of values for feature TA-RF-47 :150
# The number of values for feature TA-RF-48 :150
# The number of values for feature TA-RF-49 :150
# The number of values for feature TA-RF-50 :150
# The number of values for feature TA-RF-51 :150
# The number of values for feature TA-RF-52 :150
# The number of values for feature TA-RF-53 :150
# The number of values for feature TA-RF-54 :150
# The number of values for feature TA-RF-55 :150
# The number of values for feature TA-RF-56 :150
# The number of values for feature TA-RF-57 :150
# The number of values for feature TA-RF-58 :150
# The number of values for feature TA-RF-59 :150
# The number of values for feature TA-RF-60 :150
# The number of values for feature TA-RF-61 :150
# The number of values for feature TA-RF-62 :150
# The number of values for feature TA-RF-63 :150
# The number of values for feature TA-RF-64 :150
# The number of values for feature TA-RF-65 :150
# The number of values for feature TA-RF-66 :150
# The number of values for feature TA-RF-67 :150
# The number of values for feature TA-RF-68 :150
# The number of values for feature TA-RF-69 :150
# The number of values for feature TA-RF-70 :150
# The number of values for feature TA-RF-71 :150
# The number of values for feature TA-RF-72 :150
# The number of values for feature TA-RF-73 :150
# The number of values for feature TA-RF-74 :150
# The number of values for feature TA-RF-75 :150
# The number of values for feature TA-RF-76 :150
# The number of values for feature TA-RF-77 :150
# The number of values for feature TA-RF-78 :150
# The number of values for feature TA-RF-79 :150
# The number of values for feature TA-RF-80 :150
# The number of values for feature TA-RF-81 :150
# The number of values for feature TA-RF-82 :150
# The number of values for feature TA-RF-83 :150
# The number of values for feature TA-RF-84 :150
# The number of values for feature TA-RF-85 :150
# The number of values for feature TA-RF-86 :150
# The number of values for feature TA-RF-87 :150
# The number of values for feature TA-RF-88 :150
# The number of values for feature TA-RF-89 :150
# The number of values for feature TA-RF-90 :150
# The number of values for feature TA-RF-91 :150
# The number of values for feature TA-RF-92 :150
# The number of values for feature TA-RF-93 :150
# The number of values for feature TA-RF-94 :150
# The number of values for feature TA-RF-95 :150
# The number of values for feature TA-RF-96 :150
# The number of values for feature TA-RF-97 :150
# The number of values for feature TA-RF-98 :150
# The number of values for feature TA-RF-99 :150
# The number of values for feature TA-RF-100 :150
# The number of values for feature G-MH-0 :150
# The number of values for feature G-MH-1 :150
# The number of values for feature G-MH-2 :150
# The number of values for feature G-MH-3 :150
# The number of values for feature G-MH-4 :150
# The number of values for feature G-MH-5 :150
# The number of values for feature G-MH-6 :150
# The number of values for feature G-MH-7 :150
# The number of values for feature G-MH-8 :150
# The number of values for feature G-MH-9 :150
# The number of values for feature G-MH-10 :150
# The number of values for feature G-MH-11 :150
# The number of values for feature G-MH-12 :150
# The number of values for feature G-MH-13 :150
# The number of values for feature G-MH-14 :150
# The number of values for feature G-MH-15 :150
# The number of values for feature G-MH-16 :150
# The number of values for feature G-MH-17 :150
# The number of values for feature G-MH-18 :150
# The number of values for feature G-MH-19 :150
# The number of values for feature G-MH-20 :150
# The number of values for feature G-MH-21 :150
# The number of values for feature G-MH-22 :150
# The number of values for feature G-MH-23 :150
# The number of values for feature G-MH-24 :150
# The number of values for feature G-MH-25 :150
# The number of values for feature G-MH-26 :150
# The number of values for feature G-MH-27 :150
# The number of values for feature G-MH-28 :150
# The number of values for feature G-MH-29 :150
# The number of values for feature G-MH-30 :150
# The number of values for feature G-MH-31 :150
# The number of values for feature G-MH-32 :150
# The number of values for feature G-MH-33 :150
# The number of values for feature G-MH-34 :150
# The number of values for feature G-MH-35 :150
# The number of values for feature G-MH-36 :150
# The number of values for feature G-MH-37 :150
# The number of values for feature G-MH-38 :150
# The number of values for feature G-MH-39 :150
# The number of values for feature G-MH-40 :150
# The number of values for feature G-MH-41 :150
# The number of values for feature G-MH-42 :150
# The number of values for feature G-MH-43 :150
# The number of values for feature G-MH-44 :150
# The number of values for feature G-MH-45 :150
# The number of values for feature G-MH-46 :150
# The number of values for feature G-MH-47 :150
# The number of values for feature G-MH-48 :150
# The number of values for feature G-MH-49 :150
# The number of values for feature G-MH-50 :150
# The number of values for feature G-MH-51 :150
# The number of values for feature G-MH-52 :150
# The number of values for feature G-MH-53 :150
# The number of values for feature G-MH-54 :150
# The number of values for feature G-MH-55 :150
# The number of values for feature G-MH-56 :150
# The number of values for feature G-MH-57 :150
# The number of values for feature G-MH-58 :150
# The number of values for feature G-MH-59 :150
# The number of values for feature G-MH-60 :150
# The number of values for feature G-MH-61 :150
# The number of values for feature G-MH-62 :150
# The number of values for feature G-MH-63 :150
# The number of values for feature G-MH-64 :150
# The number of values for feature G-MH-65 :150
# The number of values for feature G-MH-66 :150
# The number of values for feature G-MH-67 :150
# The number of values for feature G-MH-68 :150
# The number of values for feature G-MH-69 :150
# The number of values for feature G-MH-70 :150
# The number of values for feature G-MH-71 :150
# The number of values for feature G-MH-72 :150
# The number of values for feature G-MH-73 :150
# The number of values for feature G-MH-74 :150
# The number of values for feature G-MH-75 :150
# The number of values for feature G-MH-76 :150
# The number of values for feature G-MH-77 :150
# The number of values for feature G-MH-78 :150
# The number of values for feature G-MH-79 :150
# The number of values for feature G-MH-80 :150
# The number of values for feature G-MH-81 :150
# The number of values for feature G-MH-82 :150
# The number of values for feature G-MH-83 :150
# The number of values for feature G-MH-84 :150
# The number of values for feature G-MH-85 :150
# The number of values for feature G-MH-86 :150
# The number of values for feature G-MH-87 :150
# The number of values for feature G-MH-88 :150
# The number of values for feature G-MH-89 :150
# The number of values for feature G-MH-90 :150
# The number of values for feature G-MH-91 :150
# The number of values for feature G-MH-92 :150
# The number of values for feature G-MH-93 :150
# The number of values for feature G-MH-94 :150
# The number of values for feature G-MH-95 :150
# The number of values for feature G-MH-96 :150
# The number of values for feature G-MH-97 :150
# The number of values for feature G-MH-98 :150
# The number of values for feature G-MH-99 :150
# The number of values for feature G-MH-100 :150
# The number of values for feature TA-G-0 :150
# The number of values for feature TA-G-1 :150
# The number of values for feature TA-G-2 :150
# The number of values for feature TA-G-3 :150
# The number of values for feature TA-G-4 :150
# The number of values for feature TA-G-5 :150
# The number of values for feature TA-G-6 :150
# The number of values for feature TA-G-7 :150
# The number of values for feature TA-G-8 :150
# The number of values for feature TA-G-9 :150
# The number of values for feature TA-G-10 :150
# The number of values for feature TA-G-11 :150
# The number of values for feature TA-G-12 :150
# The number of values for feature TA-G-13 :150
# The number of values for feature TA-G-14 :150
# The number of values for feature TA-G-15 :150
# The number of values for feature TA-G-16 :150
# The number of values for feature TA-G-17 :150
# The number of values for feature TA-G-18 :150
# The number of values for feature TA-G-19 :150
# The number of values for feature TA-G-20 :150
# The number of values for feature TA-G-21 :150
# The number of values for feature TA-G-22 :150
# The number of values for feature TA-G-23 :150
# The number of values for feature TA-G-24 :150
# The number of values for feature TA-G-25 :150
# The number of values for feature TA-G-26 :150
# The number of values for feature TA-G-27 :150
# The number of values for feature TA-G-28 :150
# The number of values for feature TA-G-29 :150
# The number of values for feature TA-G-30 :150
# The number of values for feature TA-G-31 :150
# The number of values for feature TA-G-32 :150
# The number of values for feature TA-G-33 :150
# The number of values for feature TA-G-34 :150
# The number of values for feature TA-G-35 :150
# The number of values for feature TA-G-36 :150
# The number of values for feature TA-G-37 :150
# The number of values for feature TA-G-38 :150
# The number of values for feature TA-G-39 :150
# The number of values for feature TA-G-40 :150
# The number of values for feature TA-G-41 :150
# The number of values for feature TA-G-42 :150
# The number of values for feature TA-G-43 :150
# The number of values for feature TA-G-44 :150
# The number of values for feature TA-G-45 :150
# The number of values for feature TA-G-46 :150
# The number of values for feature TA-G-47 :150
# The number of values for feature TA-G-48 :150
# The number of values for feature TA-G-49 :150
# The number of values for feature TA-G-50 :150
# The number of values for feature TA-G-51 :150
# The number of values for feature TA-G-52 :150
# The number of values for feature TA-G-53 :150
# The number of values for feature TA-G-54 :150
# The number of values for feature TA-G-55 :150
# The number of values for feature TA-G-56 :150
# The number of values for feature TA-G-57 :150
# The number of values for feature TA-G-58 :150
# The number of values for feature TA-G-59 :150
# The number of values for feature TA-G-60 :150
# The number of values for feature TA-G-61 :150
# The number of values for feature TA-G-62 :150
# The number of values for feature TA-G-63 :150
# The number of values for feature TA-G-64 :150
# The number of values for feature TA-G-65 :150
# The number of values for feature TA-G-66 :150
# The number of values for feature TA-G-67 :150
# The number of values for feature TA-G-68 :150
# The number of values for feature TA-G-69 :150
# The number of values for feature TA-G-70 :150
# The number of values for feature TA-G-71 :150
# The number of values for feature TA-G-72 :150
# The number of values for feature TA-G-73 :150
# The number of values for feature TA-G-74 :150
# The number of values for feature TA-G-75 :150
# The number of values for feature TA-G-76 :150
# The number of values for feature TA-G-77 :150
# The number of values for feature TA-G-78 :150
# The number of values for feature TA-G-79 :150
# The number of values for feature TA-G-80 :150
# The number of values for feature TA-G-81 :150
# The number of values for feature TA-G-82 :150
# The number of values for feature TA-G-83 :150
# The number of values for feature TA-G-84 :150
# The number of values for feature TA-G-85 :150
# The number of values for feature TA-G-86 :150
# The number of values for feature TA-G-87 :150
# The number of values for feature TA-G-88 :150
# The number of values for feature TA-G-89 :150
# The number of values for feature TA-G-90 :150
# The number of values for feature TA-G-91 :150
# The number of values for feature TA-G-92 :150
# The number of values for feature TA-G-93 :150
# The number of values for feature TA-G-94 :150
# The number of values for feature TA-G-95 :150
# The number of values for feature TA-G-96 :150
# The number of values for feature TA-G-97 :150
# The number of values for feature TA-G-98 :150
# The number of values for feature TA-G-99 :150
# The number of values for feature TA-G-100 :150
# The number of values for feature Stance_CCI_TA-RF :150
# The number of values for feature Stance_CCI_G-MH :150
# The number of values for feature Stance_CCI_TA-G :150
# The number of values for feature Swing_CCI_TA-RF :150
# The number of values for feature Swing_CCI_G-MH :150
# The number of values for feature Swing_CCI_TA-G :150
# The number of values for feature swing/stance_cci(TA_RF) :150
# The number of values for feature swing/stance_cci(G-MH) :150
# The number of values for feature swing/stance_CCI(TA-G) :150

# %%
# Visualize the data using seaborn Pairplots

#g = sns.pairplot(raw_data)

# Notes: Do not run this on a big dataset. Filter the columns first

# %%
raw_data.columns
# Out:
# Index(['Patient ID', 'WOMAC_total', 'WOMAC Severity', 'CCI_TA-RF', 'CCI_G-MH',
#        'CCI_TA-MH', 'CCI_G-RF', 'CCI_TA-G', 'CCI_MH-RF', 'CCI_L-H',
#        ...
#        'TA-G-100', 'Stance_CCI_TA-RF', 'Stance_CCI_G-MH', 'Stance_CCI_TA-G',
#        'Swing_CCI_TA-RF', 'Swing_CCI_G-MH', 'Swing_CCI_TA-G',
#        'swing/stance_cci(TA_RF)', 'swing/stance_cci(G-MH)',
#        'swing/stance_CCI(TA-G)'],
#       dtype='object', length=785)

# %%
# Visualising a Subset of our data - important features

g = sns.pairplot(raw_data[['WOMAC Severity', 'WOMAC_total', 'CCI_TA-RF']], hue = 'WOMAC Severity', height = 5)

# %%
# Visualising a Subset of our data - important features

'''g = sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, col = 'Day_Name', col_wrap = 3, height = 5, 
              scatter_kws = {'color':'green'}, ci = False)'''
# Out:
# "g = sns.lmplot(x = 'Marketing Spend', y = 'Revenue', data = raw_data, col = 'Day_Name', col_wrap = 3, height = 5, \n              scatter_kws = {'color':'green'}, ci = False)"

# %%
# Visualising a Subset of our data - important features

g = sns.lmplot(x="Actual Value", y="Predicted Value", data = pred_y_df, height = 5, 
              scatter_kws = {'color':'green'}, ci = False)

# %%
lm = LinearRegression(fit_intercept = True)
lm.fit(X_train, y_train)

y_pred = lm.predict(X_train)
# SK-Learn official doc: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
# Model Accuracy on training dataset

print('The Accuracy  on the training dataset is: ', lm.score(X_train, y_train) )
print('The Accuracy n2  on the training dataset is: ',r2_score(y_train,y_pred) )   

print("")
# Model Accuracy on testing dataset
print('The Accuracy  on the testing dataset is: ', lm.score(X_test, y_test) )

print("")
# The Root Mean Squared Error (RMSE)
print('The RMSE  on the training dataset is: ',sqrt(mean_squared_error(y_train,y_pred)))
print('The RMSE  on the testing dataset is: ',sqrt(mean_squared_error(y_test,lm.predict(X_test))))

print("")
# The Mean Absolute Error (MAE)
print('The MAE  on the training dataset is: ',mean_absolute_error(y_train,y_pred))
print('The MAE  on the testing dataset is: ',mean_absolute_error(y_test,lm.predict(X_test)))


print("")
# Coefficients
#print('Coefficients: ', lm.coef_ )

print("")
# The Intercept
print('Intercept: ', lm.intercept_)


# R2 Link: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html
# RMSE Link: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
# MAE Link: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
# Out:
# The Accuracy  on the training dataset is:  0.688905733259865
# The Accuracy n2  on the training dataset is:  0.688905733259865
#
# The Accuracy  on the testing dataset is:  -3.2229507667144723
#
# The RMSE  on the training dataset is:  9.499589638095417
# The RMSE  on the testing dataset is:  38.43597599976825
#
# The MAE  on the training dataset is:  7.711270351868264
# The MAE  on the testing dataset is:  23.88932410979311
#
#
# Intercept:  -10515.894225036884

# %%
# Plotting Actuals Vs Predicted

plt.figure(figsize=(15,10))

plt.scatter(y_train, y_pred, c='green')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', c='red', lw=3)
plt.xlabel('Actuals')
plt.ylabel('Predicted Values')
plt.title('Actuals Vs Predicted Values')
# Out:
# Text(0.5, 1.0, 'Actuals Vs Predicted Values')

# %%
# Ploting Residuals

plt.figure(figsize=(15,10))

sns.residplot(y_train, y_pred, color='green')
plt.xlabel('Actual Revenue')
plt.ylabel('Residuals')
plt.title('Actuals Vs Residuals')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Actuals Vs Residuals')

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit(X_train, y_train)
y_pred =reg.predict(X_test)
print(reg.coef_)
reg.intercept_
# Out:
# [0.475090 -0.069313 0.117401 -0.047814 -0.847905 0.083476 0.086732
#  -0.244414 0.192485 0.265421 0.585085 -2.390982 9.791808 -3.689827
#  -0.573201 -1.198537 0.903473 -0.573201 -4.174027 0.903473 -1.366254
#  1.223253 0.057429 -1.603804 0.721379 0.011288 0.058346 0.068437 0.017924
#  0.026179 0.071731 0.016889 0.145625 0.014892 0.013385 -0.051548 0.127702
#  0.177409 0.380009 0.615192 0.390660 -0.899495 -0.547986 -0.123498
#  0.202943 -0.192767 -0.199289 -0.146610 0.125059 0.067756 -0.489814
#  -0.079592 0.458192 0.185756 0.066938 6.506158 5.051314 -2.679487
#  -1.767950 -7.370018 -3.810313 22.654325 -14.803871 -0.881989 -0.552755
#  -3.864515 3.283259 1.442443 0.648584 -1.169023 1.063730 10.295106
#  -12.782635 -7.579549 -5.686438 -0.258491 -0.021936 0.559320 -0.257357
#  -0.055644 0.311308 3.651305 1.068921 -0.418649]
# 201.56774328892305

# %%
from sklearn import linear_model
reg = linear_model.Lasso(alpha=0.1)
reg.fit(X_train, y_train)

reg.predict(X_test)
reg.coef_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.280e+03, tolerance: 3.481e+00
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# array([0.194069, -0.104604, 0.098692, -0.055791, -0.194968, 0.103329,
#        0.100709, -0.184937, 0.077971, 0.394791, 0.369334, -2.177076,
#        0.000000, -2.072756, 0.000000, 0.557434, 0.000000, 0.000000,
#        -4.135464, 1.357614, -0.670088, 0.842713, -0.160901, -1.072251,
#        0.148649, 0.001491, 0.079467, 0.104698, -0.036930, 0.032008,
#        0.085180, -0.000000, 0.131183, 0.000000, 0.000000, -0.002947,
#        0.075355, -0.002850, 0.002813, 0.014053, -0.003190, -0.004727,
#        0.003069, -0.003705, -0.000178, 0.001679, 0.000274, -0.005635,
#        -0.004096, -0.001670, 0.001282, -0.000532, 0.001080, -0.000360,
#        0.000011, 0.000000, 0.000000, 0.000000, 0.000000, -2.604823,
#        -0.000000, 11.144906, -6.700124, -1.701273, -0.000000, -0.403298,
#        1.720286, 0.925789, 0.366845, -0.336756, 0.402940, 0.000000,
#        -0.000000, -0.000000, -0.000000, -0.080110, -0.023234, 0.126965,
#        -0.132928, -0.024392, 0.070972, 3.000047, -0.312019, 0.000000])

# %%
from sklearn import linear_model
reg = linear_model.LassoLars(alpha=.1, normalize=False)
reg.fit(X_train, y_train)
reg.predict(X_test)
reg.coef_
# Out:
# array([0.413026, -0.146837, 0.149404, -0.041660, -0.672232, 0.098434,
#        0.058283, -0.230719, 0.222254, 0.189825, 0.533961, -2.160687,
#        0.000000, -2.287022, 0.000000, 0.217136, 0.000000, 0.000000,
#        -4.135822, 0.000000, -2.026547, 0.901427, -0.180084, -1.233090,
#        0.325158, 0.020113, 0.070263, 0.111435, 0.000000, 0.031529,
#        0.086839, 0.000000, 0.095299, 0.000000, 0.000000, -0.007113,
#        0.121807, -0.002323, 0.000441, 0.016837, 0.000000, 0.000000,
#        0.000000, 0.000000, -0.006352, 0.000000, 0.001368, -0.002787,
#        0.000000, 0.000000, 0.000000, -0.002819, 0.000000, 0.000000,
#        -0.004937, 0.000000, 0.000000, 0.000000, 0.000000, -3.448459,
#        0.000000, 13.835489, -8.542450, -1.511851, -0.183347, -1.002954,
#        2.221028, 0.883770, 0.290956, -0.523230, 0.662547, 0.000000,
#        0.000000, 0.000000, 0.000000, -0.216711, 0.019238, 0.442204,
#        -0.227219, -0.014668, 0.241754, 3.340864, 0.000000, 0.000000])

# %%
from sklearn import linear_model

reg = linear_model.BayesianRidge()
reg.fit(X_train, y_train)
reg.predict(X_test)
reg.coef_
# Out:
# array([-0.000084, -0.000001, -0.000039, 0.000002, -0.000034, -0.000026,
#        0.000026, -0.000079, 0.000019, -0.000046, -0.000063, -0.000033,
#        0.000000, -0.000007, 0.000006, 0.000004, 0.000003, 0.000006,
#        0.000002, 0.000003, -0.000004, -0.000003, 0.000001, 0.000016,
#        -0.000018, 0.000015, 0.000059, 0.000050, -0.000012, -0.000020,
#        0.000043, 0.000016, 0.000040, -0.000035, -0.000016, -0.000035,
#        0.000052, 0.000096, -0.000142, 0.000968, -0.000610, 0.000078,
#        0.000179, -0.000023, -0.000257, 0.000413, 0.000933, -0.001202,
#        -0.001171, 0.000806, -0.000158, -0.000182, -0.000135, 0.000870,
#        -0.001187, 0.000000, 0.000000, 0.000000, -0.000000, -0.000001,
#        -0.000000, 0.000001, -0.000000, -0.000006, 0.000000, 0.000004,
#        -0.000001, 0.000009, -0.000000, -0.000010, 0.000007, 0.000000,
#        -0.000000, -0.000000, -0.000000, -0.000011, -0.000046, 0.000077,
#        -0.000211, 0.000139, -0.000254, 0.000000, 0.000002, -0.000001])

# %%
from sklearn.linear_model import TweedieRegressor

reg = TweedieRegressor(power=1, alpha=0.5, link='log')
reg.fit(X_train, y_train)
reg.predict(X_test)
reg.coef_


reg.intercept_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_glm/link.py:90: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_glm/link.py:93: RuntimeWarning: overflow encountered in exp
#   return np.exp(lin_pred)
# /usr/local/lib/python3.7/dist-packages/sklearn/_loss/glm_distribution.py:132: RuntimeWarning: invalid value encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# /usr/local/lib/python3.7/dist-packages/sklearn/_loss/glm_distribution.py:323: RuntimeWarning: invalid value encountered in add
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# /usr/local/lib/python3.7/dist-packages/sklearn/_loss/glm_distribution.py:132: RuntimeWarning: divide by zero encountered in true_divide
#   return -2 * (y - y_pred) / self.unit_variance(y_pred)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_glm/glm.py:42: RuntimeWarning: invalid value encountered in multiply
#   temp = d1 * family.deviance_derivative(y, y_pred, weights)
# /usr/local/lib/python3.7/dist-packages/sklearn/_loss/glm_distribution.py:323: RuntimeWarning: divide by zero encountered in true_divide
#   dev = 2 * (xlogy(y, y / y_pred) - y + y_pred)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_glm/glm.py:323: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# 3.8478399766512332

# %%
from sklearn.preprocessing import PolynomialFeatures
import numpy as np



poly = PolynomialFeatures(degree=2)
poly.fit_transform(X)
# Out:
# array([[1.000000, 144.900000, 66.000000, ..., 0.189448, 0.893212,
#         4.211320],
#        [1.000000, 99.100000, 123.600000, ..., 1.217069, 1.831610,
#         2.756454],
#        [1.000000, 90.400000, 160.100000, ..., 0.411466, 1.739617,
#         7.354839],
#        ...,
#        [1.000000, 106.880000, 94.730000, ..., 0.410155, 0.733703,
#         1.312479],
#        [1.000000, 129.860000, 135.420000, ..., 0.337849, 0.828947,
#         2.033903],
#        [1.000000, 117.760000, 69.860000, ..., 0.866888, 1.487069,
#         2.550934]])

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
import numpy as np
model = Pipeline([('poly', PolynomialFeatures(degree=3)),
                  ('linear', LinearRegression(fit_intercept=False))])
# fit to an order-3 polynomial data
x = np.arange(5)
y = 3 - 2 * x + x ** 2 - x ** 3
model = model.fit(x[:, np.newaxis], y)
model.named_steps['linear'].coef_
# Out:
# array([3.000000, -2.000000, 1.000000, -1.000000])
